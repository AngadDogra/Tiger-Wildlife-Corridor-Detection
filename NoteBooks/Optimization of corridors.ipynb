# %%
pip install numpy matplotlib scipy
# Out:
# Requirement already satisfied: numpy in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (1.24.3)
# Requirement already satisfied: matplotlib in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (3.7.2)
# Requirement already satisfied: scipy in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (1.11.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: C:\Users\CJ\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import distance

# Define the grid dimensions (e.g., a 10x10 grid)
grid_size = 10
grid = np.zeros((grid_size, grid_size))

# Define risky areas (wildlife corridors, human activity zones)
# For simplicity, let's manually mark some risky zones
risky_zones = [(2, 3), (5, 7), (8, 1), (6, 6), (3, 4)]
for zone in risky_zones:
    grid[zone] = 1  # Marking risky areas with 1

# Visualize the grid and risky areas
def plot_grid(grid, devices=None):
    plt.imshow(grid, cmap="Greys", origin='lower')
    plt.colorbar(label="Risk Level")
    if devices:
        devices = np.array(devices)
        plt.scatter(devices[:, 1], devices[:, 0], color='red', label='Devices', marker='x')
    plt.title("Risky Zones and Device Placements")
    plt.legend()
    plt.show()

plot_grid(grid)

# Function to calculate coverage based on distance
def is_covered(device, zone, coverage_radius):
    return distance.euclidean(device, zone) <= coverage_radius

# Greedy Algorithm for optimizing device placement
def optimize_device_placement(grid, coverage_radius):
    risky_zones = np.argwhere(grid == 1)
    devices = []
    covered_zones = set()

    while len(covered_zones) < len(risky_zones):
        # Find the most uncovered risky zone
        uncovered_zones = [zone for zone in risky_zones if tuple(zone) not in covered_zones]
        if not uncovered_zones:
            break
        # Place device at an uncovered risky zone
        new_device = uncovered_zones[0]  # Can be improved by more intelligent choice
        devices.append(new_device)
        
        # Mark zones covered by this new device
        for zone in risky_zones:
            if is_covered(new_device, zone, coverage_radius):
                covered_zones.add(tuple(zone))
    
    return devices

# Define the coverage radius (how far each device can "see")
coverage_radius = 2.5

# Optimize device placement
device_locations = optimize_device_placement(grid, coverage_radius)

# Visualize the result
plot_grid(grid, device_locations)

print("Device Locations:", device_locations)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Device Locations: [array([2, 3], dtype=int64), array([5, 7], dtype=int64), array([8, 1], dtype=int64)]

# %%
pip install geopandas folium seaborn matplotlib
# Out:
# Collecting geopandas
#   Obtaining dependency information for geopandas from https://files.pythonhosted.org/packages/c4/64/7d344cfcef5efddf9cf32f59af7f855828e9d74b5f862eddf5bfd9f25323/geopandas-1.0.1-py3-none-any.whl.metadata
#   Downloading geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting folium
#   Obtaining dependency information for folium from https://files.pythonhosted.org/packages/ae/6d/18a7546e1748ecdd6ed7cd00d3f183faf1df08bd4f5e5e0eb3e72458b862/folium-0.17.0-py2.py3-none-any.whl.metadata
#   Downloading folium-0.17.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: seaborn in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (0.12.2)
# Requirement already satisfied: matplotlib in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (3.7.2)
# Requirement already satisfied: numpy>=1.22 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from geopandas) (1.24.3)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Obtaining dependency information for pyogrio>=0.7.2 from https://files.pythonhosted.org/packages/94/8d/24f21e6a93ca418231aee3bddade7a0766c89c523832f29e08a8860f83e6/pyogrio-0.10.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading pyogrio-0.10.0-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from geopandas) (2.2.2)
# Collecting pyproj>=3.3.0 (from geopandas)
#   Obtaining dependency information for pyproj>=3.3.0 from https://files.pythonhosted.org/packages/26/0c/b084e8839a117eaad8cb4fbaa81bbb24c6f183de0ee95c6c4e2770ab6f09/pyproj-3.7.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading pyproj-3.7.0-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Obtaining dependency information for shapely>=2.0.0 from https://files.pythonhosted.org/packages/b1/5a/6a67d929c467a1973b6bb9f0b00159cc343b02bf9a8d26db1abd2f87aa23/shapely-2.0.6-cp311-cp311-win_amd64.whl.metadata
#   Downloading shapely-2.0.6-cp311-cp311-win_amd64.whl.metadata (7.2 kB)
# Collecting branca>=0.6.0 (from folium)
#   Obtaining dependency information for branca>=0.6.0 from https://files.pythonhosted.org/packages/fc/be/720f85abacd654ec86f1431bc7c004eae74417bd9d0e7a2bc43601062627/branca-0.8.0-py3-none-any.whl.metadata
#   Downloading branca-0.8.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: requests in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from folium) (2.32.3)
# Collecting xyzservices (from folium)
#   Obtaining dependency information for xyzservices from https://files.pythonhosted.org/packages/4c/d3/e07ce413d16ef64e885bea37551eac4c5ca3ddd440933f9c94594273d0d9/xyzservices-2024.9.0-py3-none-any.whl.metadata
#   Downloading xyzservices-2024.9.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: certifi in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2023.7.22)
# Requirement already satisfied: six>=1.5 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from requests->folium) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cj\appdata\local\programs\python\python311\lib\site-packages (from requests->folium) (1.26.16)
# Note: you may need to restart the kernel to use updated packages.
# Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
#    ---------------------------------------- 0.0/323.6 kB ? eta -:--:--
#    --------------------------------------- 323.6/323.6 kB 10.1 MB/s eta 0:00:00
# Downloading folium-0.17.0-py2.py3-none-any.whl (108 kB)
#    ---------------------------------------- 0.0/108.4 kB ? eta -:--:--
#    ---------------------------------------- 108.4/108.4 kB ? eta 0:00:00
# Downloading branca-0.8.0-py3-none-any.whl (25 kB)
# Downloading pyogrio-0.10.0-cp311-cp311-win_amd64.whl (16.2 MB)
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#    - -------------------------------------- 0.4/16.2 MB 8.7 MB/s eta 0:00:02
#    -- ------------------------------------- 0.9/16.2 MB 11.2 MB/s eta 0:00:02
#    --- ------------------------------------ 1.3/16.2 MB 9.0 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.6/16.2 MB 9.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.1/16.2 MB 9.4 MB/s eta 0:00:02
#    ------ --------------------------------- 2.5/16.2 MB 8.7 MB/s eta 0:00:02
#    ------- -------------------------------- 2.8/16.2 MB 9.1 MB/s eta 0:00:02
#    -------- ------------------------------- 3.3/16.2 MB 8.7 MB/s eta 0:00:02
#    --------- ------------------------------ 3.7/16.2 MB 8.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.0/16.2 MB 8.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.5/16.2 MB 8.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.8/16.2 MB 8.6 MB/s eta 0:00:02
#    ------------ --------------------------- 5.2/16.2 MB 8.6 MB/s eta 0:00:02
#    ------------- -------------------------- 5.7/16.2 MB 8.6 MB/s eta 0:00:02
#    -------------- ------------------------- 6.0/16.2 MB 8.6 MB/s eta 0:00:02
#    --------------- ------------------------ 6.4/16.2 MB 8.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.8/16.2 MB 8.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 7.2/16.2 MB 8.5 MB/s eta 0:00:02
#    ------------------ --------------------- 7.6/16.2 MB 8.6 MB/s eta 0:00:01
#    ------------------- -------------------- 8.0/16.2 MB 8.6 MB/s eta 0:00:01
#    -------------------- ------------------- 8.4/16.2 MB 8.5 MB/s eta 0:00:01
#    --------------------- ------------------ 8.8/16.2 MB 8.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 9.2/16.2 MB 8.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.6/16.2 MB 8.4 MB/s eta 0:00:01
#    ------------------------ --------------- 10.0/16.2 MB 8.5 MB/s eta 0:00:01
#    ------------------------- -------------- 10.4/16.2 MB 8.4 MB/s eta 0:00:01
#    -------------------------- ------------- 10.8/16.2 MB 8.3 MB/s eta 0:00:01
#    --------------------------- ------------ 11.2/16.2 MB 8.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.5/16.2 MB 8.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.9/16.2 MB 8.4 MB/s eta 0:00:01
#    ------------------------------ --------- 12.3/16.2 MB 8.3 MB/s eta 0:00:01
#    ------------------------------- -------- 12.7/16.2 MB 8.4 MB/s eta 0:00:01
#    -------------------------------- ------- 13.1/16.2 MB 8.3 MB/s eta 0:00:01
#    --------------------------------- ------ 13.5/16.2 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.9/16.2 MB 8.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.3/16.2 MB 8.4 MB/s eta 0:00:01
#    ------------------------------------ --- 14.7/16.2 MB 8.3 MB/s eta 0:00:01
#    ------------------------------------- -- 15.0/16.2 MB 8.4 MB/s eta 0:00:01
#    -------------------------------------- - 15.5/16.2 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------  15.8/16.2 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------  16.2/16.2 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 16.2/16.2 MB 8.0 MB/s eta 0:00:00
# Downloading pyproj-3.7.0-cp311-cp311-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.2 MB 9.6 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.8/6.2 MB 10.8 MB/s eta 0:00:01
#    -------- ------------------------------- 1.3/6.2 MB 10.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.6/6.2 MB 8.8 MB/s eta 0:00:01
#    ------------- -------------------------- 2.1/6.2 MB 9.4 MB/s eta 0:00:01
#    --------------- ------------------------ 2.5/6.2 MB 8.7 MB/s eta 0:00:01
#    ------------------ --------------------- 2.8/6.2 MB 9.1 MB/s eta 0:00:01
#    -------------------- ------------------- 3.2/6.2 MB 9.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.6/6.2 MB 8.6 MB/s eta 0:00:01
#    ------------------------- -------------- 4.0/6.2 MB 8.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.4/6.2 MB 8.6 MB/s eta 0:00:01
#    ------------------------------ --------- 4.8/6.2 MB 8.8 MB/s eta 0:00:01
#    --------------------------------- ------ 5.2/6.2 MB 8.5 MB/s eta 0:00:01
#    ------------------------------------ --- 5.6/6.2 MB 8.6 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.2 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  6.2/6.2 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 8.3 MB/s eta 0:00:00
# Downloading shapely-2.0.6-cp311-cp311-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    -------------- ------------------------- 0.5/1.4 MB 10.9 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.4 MB 10.0 MB/s eta 0:00:01
#    ------------------------------------- -- 1.4/1.4 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 9.2 MB/s eta 0:00:00
# Downloading xyzservices-2024.9.0-py3-none-any.whl (85 kB)
#    ---------------------------------------- 0.0/85.1 kB ? eta -:--:--
#    ---------------------------------------- 85.1/85.1 kB ? eta 0:00:00
# Installing collected packages: xyzservices, shapely, pyproj, pyogrio, branca, geopandas, folium
# Successfully installed branca-0.8.0 folium-0.17.0 geopandas-1.0.1 pyogrio-0.10.0 pyproj-3.7.0 shapely-2.0.6 xyzservices-2024.9.0
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: C:\Users\CJ\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
import geopandas as gpd
import pandas as pd
import folium
from folium.plugins import HeatMap

# Load India's map shapefile from the specified folder
india_map = gpd.read_file("gadm41_IND_shp/gadm41_IND_3.shp")  # Ensure this path is correct

# Load tiger population data (assuming you have lat/lon and population density)
tiger_population = pd.read_excel("TigerDataIBM.xlsx")  # Modify based on actual sheet
# Example DataFrame structure: ['State', 'Lat', 'Lon', 'TigerCount']
# Ensure you have these columns in your Excel sheet.

# Load poaching data (Lat/Lon of high-risk poaching areas)
poaching_data = pd.read_csv("poaching_data.csv")  # Example file containing Lat/Lon of poaching incidents
# Ensure your CSV file has 'Lat' and 'Lon' columns.

# Proposed device locations (generated through optimization)
device_locations = [(21.5, 79.1), (27.6, 81.6)]  # Example: Add your own device placements (Lat, Lon)

# Create a base map using Folium
m = folium.Map(location=[23.5937, 80.9629], zoom_start=5, tiles='CartoDB positron')

# Plot tiger population as a heatmap
heatmap_data = [[row['Lat'], row['Lon'], row['TigerCount']] for index, row in tiger_population.iterrows()]

# Create the heatmap layer
HeatMap(heatmap_data, radius=15, max_zoom=13).add_to(m)

# Plot poaching data as red circles
for _, row in poaching_data.iterrows():
    folium.CircleMarker(
        location=(row['Lat'], row['Lon']),
        radius=6,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup="Poaching Incident"
    ).add_to(m)

# Plot device locations as blue markers
for device in device_locations:
    folium.Marker(
        location=device,
        popup="Proposed Device",
        icon=folium.Icon(color='blue')
    ).add_to(m)

# Display the map and save it as an HTML file
m.save('tiger_poaching_map.html')
m
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Lat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 25
#      22 m = folium.Map(location=[23.5937, 80.9629], zoom_start=5, tiles='CartoDB positron')
#      24 # Plot tiger population as a heatmap
# ---> 25 heatmap_data = [[row['Lat'], row['Lon'], row['TigerCount']] for index, row in tiger_population.iterrows()]
#      27 # Create the heatmap layer
#      28 HeatMap(heatmap_data, radius=15, max_zoom=13).add_to(m)
#
# Cell In[8], line 25, in <listcomp>(.0)
#      22 m = folium.Map(location=[23.5937, 80.9629], zoom_start=5, tiles='CartoDB positron')
#      24 # Plot tiger population as a heatmap
# ---> 25 heatmap_data = [[row['Lat'], row['Lon'], row['TigerCount']] for index, row in tiger_population.iterrows()]
#      27 # Create the heatmap layer
#      28 HeatMap(heatmap_data, radius=15, max_zoom=13).add_to(m)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Lat'

# %%
import geopandas as gpd
import pandas as pd
import folium
from folium.plugins import HeatMap

# Load India's map shapefile from the specified folder
india_map = gpd.read_file("gadm41_IND_shp/gadm41_IND_3.shp")  # Ensure this path is correct

# Load tiger population data (assuming you have lat/lon and population density)
tiger_population = pd.read_excel("TigerDataIBM.xlsx")  # Modify based on actual sheet

# Print column names to debug
print("Tiger Population Columns:", tiger_population.columns)

# Strip any extra spaces from the column names
tiger_population.columns = tiger_population.columns.str.strip()

# Check the updated column names after stripping spaces
print("Updated Tiger Population Columns:", tiger_population.columns)

# Prepare heatmap data
try:
    heatmap_data = [[row['Lat'], row['Lon'], row['TigerCount']] for index, row in tiger_population.iterrows()]
except KeyError as e:
    print(f"KeyError: {e}. Please check your column names in the DataFrame.")

# Load poaching data (Lat/Lon of high-risk poaching areas)
poaching_data = pd.read_csv("poaching_data.csv")  # Example file containing Lat/Lon of poaching incidents

# Proposed device locations (generated through optimization)
device_locations = [(21.5, 79.1), (27.6, 81.6)]  # Example: Add your own device placements (Lat, Lon)

# Create a base map using Folium
m = folium.Map(location=[23.5937, 80.9629], zoom_start=5, tiles='CartoDB positron')

# Create the heatmap layer
if 'Lat' in tiger_population.columns and 'Lon' in tiger_population.columns and 'TigerCount' in tiger_population.columns:
    HeatMap(heatmap_data, radius=15, max_zoom=13).add_to(m)

# Plot poaching data as red circles
for _, row in poaching_data.iterrows():
    folium.CircleMarker(
        location=(row['Lat'], row['Lon']),
        radius=6,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup="Poaching Incident"
    ).add_to(m)

# Plot device locations as blue markers
"""
for device in device_locations:
    folium.Marker(
        location=device,
        popup="Proposed Device",
        icon=folium.Icon(color='blue')
    ).add_to(m)
"""
# Display the map and save it as an HTML file
m.save('tiger_poaching_map.html')
m
# Out:
# Tiger Population Columns: Index(['ID', 'State/UT', 'Region/National Park', 'Tiger Population',
#        'Population Estimate', 'Conservation Status', 'Habitat Type', 'Threats',
#        'Conservation Initiatives', 'Tourism Impact', 'Latitude', 'Longitude',
#        'Notes'],
#       dtype='object')
# Updated Tiger Population Columns: Index(['ID', 'State/UT', 'Region/National Park', 'Tiger Population',
#        'Population Estimate', 'Conservation Status', 'Habitat Type', 'Threats',
#        'Conservation Initiatives', 'Tourism Impact', 'Latitude', 'Longitude',
#        'Notes'],
#       dtype='object')
# KeyError: 'Lat'. Please check your column names in the DataFrame.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_beff5913106cbb77876f13e3fa60e765 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_beff5913106cbb77876f13e3fa60e765&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_beff5913106cbb77876f13e3fa60e765 = L.map(
#                 &quot;map_beff5913106cbb77876f13e3fa60e765&quot;,
#                 {
#                     center: [23.5937, 80.9629],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7038babb50927df6e0642097d9fb96f2 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7038babb50927df6e0642097d9fb96f2.addTo(map_beff5913106cbb77876f13e3fa60e765);
#
#
#             var circle_marker_4d5dcaa1912cc8856c77a98936bfc68d = L.circleMarker(
#                 [26.9205, 80.7734],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_beff5913106cbb77876f13e3fa60e765);
#
#
#         var popup_6312ffc0341652069c4b6c2b698b6dd9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_36d6d7bdbd3b787e5744ecedfc88f47e = $(`&lt;div id=&quot;html_36d6d7bdbd3b787e5744ecedfc88f47e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Poaching Incident&lt;/div&gt;`)[0];
#                 popup_6312ffc0341652069c4b6c2b698b6dd9.setContent(html_36d6d7bdbd3b787e5744ecedfc88f47e);
#
#
#
#         circle_marker_4d5dcaa1912cc8856c77a98936bfc68d.bindPopup(popup_6312ffc0341652069c4b6c2b698b6dd9)
#         ;
#
#
#
#
#             var circle_marker_47658743cb5e5981ddd5bda3921a9d0c = L.circleMarker(
#                 [25.9785, 86.4706],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_beff5913106cbb77876f13e3fa60e765);
#
#
#         var popup_2b4c56f7fbdaa90668c88eb707baec30 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cbe310f9cd7d2b998e9e1fe25088ff1b = $(`&lt;div id=&quot;html_cbe310f9cd7d2b998e9e1fe25088ff1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Poaching Incident&lt;/div&gt;`)[0];
#                 popup_2b4c56f7fbdaa90668c88eb707baec30.setContent(html_cbe310f9cd7d2b998e9e1fe25088ff1b);
#
#
#
#         circle_marker_47658743cb5e5981ddd5bda3921a9d0c.bindPopup(popup_2b4c56f7fbdaa90668c88eb707baec30)
#         ;
#
#
#
#
#             var circle_marker_5281b2bdd9cdb8920fb41f78873769bf = L.circleMarker(
#                 [21.6202, 80.6965],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_beff5913106cbb77876f13e3fa60e765);
#
#
#         var popup_0889f40c960eb01154cb390a8237b5af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_effc295c226afe6fd0715154ae7e461b = $(`&lt;div id=&quot;html_effc295c226afe6fd0715154ae7e461b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Poaching Incident&lt;/div&gt;`)[0];
#                 popup_0889f40c960eb01154cb390a8237b5af.setContent(html_effc295c226afe6fd0715154ae7e461b);
#
#
#
#         circle_marker_5281b2bdd9cdb8920fb41f78873769bf.bindPopup(popup_0889f40c960eb01154cb390a8237b5af)
#         ;
#
#
#
#
#             var circle_marker_e083026624efca492ee95f455cc4dc53 = L.circleMarker(
#                 [22.3575, 85.6671],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quo

# %%
import geopandas as gpd
import pandas as pd
import folium
from folium.plugins import HeatMap
from sklearn.cluster import KMeans

# Load India's map shapefile from the specified folder
india_map = gpd.read_file("gadm41_IND_shp/gadm41_IND_3.shp")  # Ensure this path is correct

# Load tiger population data
tiger_population = pd.read_excel("TigerDataIBM.xlsx")  # Modify based on actual sheet

# Print column names to debug
print("Tiger Population Columns:", tiger_population.columns)

# Strip any extra spaces from the column names
tiger_population.columns = tiger_population.columns.str.strip()

# Prepare heatmap data
heatmap_data = [[row['Lat'], row['Lon'], row['TigerCount']] for index, row in tiger_population.iterrows()]

# Load poaching data (Lat/Lon of high-risk poaching areas)
poaching_data = pd.read_csv("poaching_data.csv")  # Example file containing Lat/Lon of poaching incidents

# Prepare data for clustering
poaching_coords = poaching_data[['Lat', 'Lon']].values

# Apply K-means clustering
num_devices = 5  # You can adjust the number of clusters (devices) here
kmeans = KMeans(n_clusters=num_devices)
kmeans.fit(poaching_coords)

# Get the cluster centers
device_locations = kmeans.cluster_centers_

# Create a base map using Folium
m = folium.Map(location=[23.5937, 80.9629], zoom_start=5, tiles='CartoDB positron')

# Create the heatmap layer for tiger population
HeatMap(heatmap_data, radius=15, max_zoom=13).add_to(m)

# Plot poaching data as red circles
for _, row in poaching_data.iterrows():
    folium.CircleMarker(
        location=(row['Lat'], row['Lon']),
        radius=6,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup="Poaching Incident"
    ).add_to(m)

# Plot device locations as blue markers
for device in device_locations:
    folium.Marker(
        location=(device[0], device[1]),
        popup="Proposed Device",
        icon=folium.Icon(color='blue')
    ).add_to(m)

# Display the map and save it as an HTML file
m.save('tiger_poaching_map_with_devices.html')
m
# Out:
# Tiger Population Columns: Index(['ID', 'State/UT', 'Region/National Park', 'Tiger Population',
#        'Population Estimate', 'Conservation Status', 'Habitat Type', 'Threats',
#        'Conservation Initiatives', 'Tourism Impact', 'Latitude', 'Longitude',
#        'Notes'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Lat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 20
#      17 tiger_population.columns = tiger_population.columns.str.strip()
#      19 # Prepare heatmap data
# ---> 20 heatmap_data = [[row['Lat'], row['Lon'], row['TigerCount']] for index, row in tiger_population.iterrows()]
#      22 # Load poaching data (Lat/Lon of high-risk poaching areas)
#      23 poaching_data = pd.read_csv("poaching_data.csv")  # Example file containing Lat/Lon of poaching incidents
#
# Cell In[10], line 20, in <listcomp>(.0)
#      17 tiger_population.columns = tiger_population.columns.str.strip()
#      19 # Prepare heatmap data
# ---> 20 heatmap_data = [[row['Lat'], row['Lon'], row['TigerCount']] for index, row in tiger_population.iterrows()]
#      22 # Load poaching data (Lat/Lon of high-risk poaching areas)
#      23 poaching_data = pd.read_csv("poaching_data.csv")  # Example file containing Lat/Lon of poaching incidents
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Lat'

# %%
import geopandas as gpd
import pandas as pd
import folium
from folium.plugins import HeatMap
from sklearn.cluster import KMeans

# Load India's map shapefile from the specified folder
india_map = gpd.read_file("gadm41_IND_shp/gadm41_IND_3.shp")  # Ensure this path is correct

# Load tiger population data
tiger_population = pd.read_excel("TigerDataIBM.xlsx")  # Modify based on actual sheet

# Print column names to debug
print("Tiger Population Columns:", tiger_population.columns)

# Strip any extra spaces from the column names
tiger_population.columns = tiger_population.columns.str.strip()

# Prepare heatmap data using the correct column names
heatmap_data = [[row['Latitude'], row['Longitude'], row['Tiger Population']] for index, row in tiger_population.iterrows()]

# Load poaching data (Lat/Lon of high-risk poaching areas)
poaching_data = pd.read_csv("poaching_data.csv")  # Example file containing Lat/Lon of poaching incidents

# Prepare data for clustering
poaching_coords = poaching_data[['Latitude', 'Longitude']].values  # Use correct column names

# Apply K-means clustering
num_devices = 5  # You can adjust the number of clusters (devices) here
kmeans = KMeans(n_clusters=num_devices)
kmeans.fit(poaching_coords)

# Get the cluster centers
device_locations = kmeans.cluster_centers_

# Create a base map using Folium
m = folium.Map(location=[23.5937, 80.9629], zoom_start=5, tiles='CartoDB positron')

# Create the heatmap layer for tiger population
HeatMap(heatmap_data, radius=15, max_zoom=13).add_to(m)

# Plot poaching data as red circles
for _, row in poaching_data.iterrows():
    folium.CircleMarker(
        location=(row['Latitude'], row['Longitude']),
        radius=6,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup="Poaching Incident"
    ).add_to(m)

# Plot device locations as blue markers
for device in device_locations:
    folium.Marker(
        location=(device[0], device[1]),
        popup="Proposed Device",
        icon=folium.Icon(color='blue')
    ).add_to(m)

# Display the map and save it as an HTML file
m.save('tiger_poaching_map_with_devices.html')
m
# Out:
# Tiger Population Columns: Index(['ID', 'State/UT', 'Region/National Park', 'Tiger Population',
#        'Population Estimate', 'Conservation Status', 'Habitat Type', 'Threats',
#        'Conservation Initiatives', 'Tourism Impact', 'Latitude', 'Longitude',
#        'Notes'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 26
#      23 poaching_data = pd.read_csv("poaching_data.csv")  # Example file containing Lat/Lon of poaching incidents
#      25 # Prepare data for clustering
# ---> 26 poaching_coords = poaching_data[['Latitude', 'Longitude']].values  # Use correct column names
#      28 # Apply K-means clustering
#      29 num_devices = 5  # You can adjust the number of clusters (devices) here
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Latitude', 'Longitude'], dtype='object')] are in the [columns]"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Load tiger population data
tiger_population = pd.read_csv("TigerDataIBM.xlsx")  # Replace with your actual file name
tiger_population.columns = tiger_population.columns.str.strip()  # Strip any whitespace from column names

# Print tiger population data columns to verify names
print("Tiger Population Columns:", tiger_population.columns)

# Prepare heatmap data (adjust column names if necessary)
heatmap_data = [
    [row['Latitude'], row['Longitude'], row['Tiger Population']]
    for index, row in tiger_population.iterrows()
]

# Load poaching data
poaching_data = pd.read_csv("poaching_data.csv")  # Replace with your actual file name

# Print poaching data columns to verify names
print("Poaching Data Columns:", poaching_data.columns)

# Prepare data for clustering (adjust based on actual column names)
# Change 'Latitude' and 'Longitude' if they have different names in the CSV
poaching_coords = poaching_data[['Lat', 'Lon']].values

# Apply K-means clustering
num_devices = 5  # You can adjust the number of clusters (devices) here
kmeans = KMeans(n_clusters=num_devices)
kmeans.fit(poaching_coords)

# Get the cluster centers (device locations)
device_locations = kmeans.cluster_centers_

# Print device locations
print("Device Locations (Cluster Centers):")
for i, loc in enumerate(device_locations):
    print(f"Device {i + 1}: Latitude = {loc[0]}, Longitude = {loc[1]}")

# Optional: Plotting the results
plt.figure(figsize=(10, 6))

# Plot poaching incidents
plt.scatter(poaching_coords[:, 0], poaching_coords[:, 1], c='red', label='Poaching Incidents', alpha=0.5)

# Plot device locations
plt.scatter(device_locations[:, 0], device_locations[:, 1], c='blue', label='Device Locations', marker='X', s=200)

plt.title('Poaching Incidents and Device Locations')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.legend()
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[14], line 7
#       4 from sklearn.cluster import KMeans
#       6 # Load tiger population data
# ----> 7 tiger_population = pd.read_csv("TigerDataIBM.xlsx")  # Replace with your actual file name
#       8 tiger_population.columns = tiger_population.columns.str.strip()  # Strip any whitespace from column names
#      10 # Print tiger population data columns to verify names
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:574, in pandas._libs.parsers.TextReader.__cinit__()
#
# File parsers.pyx:663, in pandas._libs.parsers.TextReader._get_header()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 15-16: invalid continuation byte

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Load tiger population data from an Excel file
tiger_population = pd.read_excel("TigerDataIBM.xlsx")  # Replace with your actual file name
tiger_population.columns = tiger_population.columns.str.strip()  # Strip any whitespace from column names

# Print tiger population data columns to verify names
print("Tiger Population Columns:", tiger_population.columns)

# Prepare heatmap data (adjust column names if necessary)
heatmap_data = [
    [row['Latitude'], row['Longitude'], row['Tiger Population']]
    for index, row in tiger_population.iterrows()
]

# Load poaching data
poaching_data = pd.read_excel("poaching_data.csv")  # Replace with your actual file name

# Print poaching data columns to verify names
print("Poaching Data Columns:", poaching_data.columns)

# Prepare data for clustering (adjust based on actual column names)
# Change 'Latitude' and 'Longitude' if they have different names in the Excel file
poaching_coords = poaching_data[['Lat', 'Lon']].values

# Apply K-means clustering
num_devices = 5  # You can adjust the number of clusters (devices) here
kmeans = KMeans(n_clusters=num_devices)
kmeans.fit(poaching_coords)

# Get the cluster centers (device locations)
device_locations = kmeans.cluster_centers_

# Print device locations
print("Device Locations (Cluster Centers):")
for i, loc in enumerate(device_locations):
    print(f"Device {i + 1}: Latitude = {loc[0]}, Longitude = {loc[1]}")

# Optional: Plotting the results
plt.figure(figsize=(10, 6))

# Plot poaching incidents
plt.scatter(poaching_coords[:, 0], poaching_coords[:, 1], c='red', label='Poaching Incidents', alpha=0.5)

# Plot device locations
plt.scatter(device_locations[:, 0], device_locations[:, 1], c='blue', label='Device Locations', marker='X', s=200)

plt.title('Poaching Incidents and Device Locations')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.legend()
plt.grid()
plt.show()
# Out:
# Tiger Population Columns: Index(['ID', 'State/UT', 'Region/National Park', 'Tiger Population',
#        'Population Estimate', 'Conservation Status', 'Habitat Type', 'Threats',
#        'Conservation Initiatives', 'Tourism Impact', 'Latitude', 'Longitude',
#        'Notes'],
#       dtype='object')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 20
#      14 heatmap_data = [
#      15     [row['Latitude'], row['Longitude'], row['Tiger Population']]
#      16     for index, row in tiger_population.iterrows()
#      17 ]
#      19 # Load poaching data
# ---> 20 poaching_data = pd.read_excel("poaching_data.csv")  # Replace with your actual file name
#      22 # Print poaching data columns to verify names
#      23 print("Poaching Data Columns:", poaching_data.columns)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1554, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
# -> 1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#    1559 engine = config.get_option(f"io.excel.{ext}.reader", silent=True)
#    1560 if engine == "auto":
#
# ValueError: Excel file format cannot be determined, you must specify an engine manually.

# %%
import geopandas as gpd
import pandas as pd
import folium
from folium.plugins import HeatMap
from sklearn.cluster import KMeans

# Load India's map shapefile from the specified folder
india_map = gpd.read_file("gadm41_IND_shp/gadm41_IND_3.shp")  # Ensure this path is correct

# Load tiger population data (assuming you have lat/lon and population density)
tiger_population = pd.read_excel("TigerDataIBM.xlsx")  # Modify based on actual sheet

# Print column names to debug
print("Tiger Population Columns:", tiger_population.columns)

# Strip any extra spaces from the column names
tiger_population.columns = tiger_population.columns.str.strip()

# Check the updated column names after stripping spaces
print("Updated Tiger Population Columns:", tiger_population.columns)

# Prepare heatmap data
try:
    heatmap_data = [[row['Lat'], row['Lon'], row['TigerCount']] for index, row in tiger_population.iterrows()]
except KeyError as e:
    print(f"KeyError: {e}. Please check your column names in the DataFrame.")

# Load poaching data (Lat/Lon of high-risk poaching areas)
poaching_data = pd.read_csv("poaching_data.csv")  # Example file containing Lat/Lon of poaching incidents

# Prepare poaching coordinates for clustering
poaching_coords = poaching_data[['Lat', 'Lon']].values

# Determine the number of clusters based on the number of poaching incidents (or adjust this number)
num_clusters = min(len(poaching_coords), 10)  # Max 10 devices or the number of incidents, whichever is smaller

# Apply K-means clustering to find device locations
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(poaching_coords)

# Get the cluster centers (device locations)
device_locations = kmeans.cluster_centers_

# Create a base map using Folium
m = folium.Map(location=[23.5937, 80.9629], zoom_start=5, tiles='CartoDB positron')

# Create the heatmap layer
if 'Lat' in tiger_population.columns and 'Lon' in tiger_population.columns and 'TigerCount' in tiger_population.columns:
    HeatMap(heatmap_data, radius=15, max_zoom=13).add_to(m)

# Plot poaching data as red circles
for _, row in poaching_data.iterrows():
    folium.CircleMarker(
        location=(row['Lat'], row['Lon']),
        radius=6,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup="Poaching Incident"
    ).add_to(m)

# Plot device locations as blue markers
for device in device_locations:
    folium.Marker(
        location=(device[0], device[1]),
        popup="Proposed Device",
        icon=folium.Icon(color='blue')
    ).add_to(m)

# Display the map and save it as an HTML file
m.save('tiger_poaching_map.html')
m
# Out:
# Tiger Population Columns: Index(['ID', 'State/UT', 'Region/National Park', 'Tiger Population',
#        'Population Estimate', 'Conservation Status', 'Habitat Type', 'Threats',
#        'Conservation Initiatives', 'Tourism Impact', 'Latitude', 'Longitude',
#        'Notes'],
#       dtype='object')
# Updated Tiger Population Columns: Index(['ID', 'State/UT', 'Region/National Park', 'Tiger Population',
#        'Population Estimate', 'Conservation Status', 'Habitat Type', 'Threats',
#        'Conservation Initiatives', 'Tourism Impact', 'Latitude', 'Longitude',
#        'Notes'],
#       dtype='object')
# KeyError: 'Lat'. Please check your column names in the DataFrame.
# C:\Users\CJ\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5928d8f5852b666cf2691229bbe5e798 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5928d8f5852b666cf2691229bbe5e798&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5928d8f5852b666cf2691229bbe5e798 = L.map(
#                 &quot;map_5928d8f5852b666cf2691229bbe5e798&quot;,
#                 {
#                     center: [23.5937, 80.9629],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_313651d7fa2531afd773801bbee92c00 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_313651d7fa2531afd773801bbee92c00.addTo(map_5928d8f5852b666cf2691229bbe5e798);
#
#
#             var circle_marker_2d2663bc0debefa4a7179a122e07284a = L.circleMarker(
#                 [26.9205, 80.7734],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5928d8f5852b666cf2691229bbe5e798);
#
#
#         var popup_ab42eebeb0efbd09950e660a574fea39 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b7bcd00f3f3ca27ddd793ff176ea3d98 = $(`&lt;div id=&quot;html_b7bcd00f3f3ca27ddd793ff176ea3d98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Poaching Incident&lt;/div&gt;`)[0];
#                 popup_ab42eebeb0efbd09950e660a574fea39.setContent(html_b7bcd00f3f3ca27ddd793ff176ea3d98);
#
#
#
#         circle_marker_2d2663bc0debefa4a7179a122e07284a.bindPopup(popup_ab42eebeb0efbd09950e660a574fea39)
#         ;
#
#
#
#
#             var circle_marker_91576c551fd1bfcb24ea8920ba77d4ac = L.circleMarker(
#                 [25.9785, 86.4706],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5928d8f5852b666cf2691229bbe5e798);
#
#
#         var popup_7a8a2a02d6c981e02017dd79c4d3319a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_56bd53f42358d688bf895b73f45bd72f = $(`&lt;div id=&quot;html_56bd53f42358d688bf895b73f45bd72f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Poaching Incident&lt;/div&gt;`)[0];
#                 popup_7a8a2a02d6c981e02017dd79c4d3319a.setContent(html_56bd53f42358d688bf895b73f45bd72f);
#
#
#
#         circle_marker_91576c551fd1bfcb24ea8920ba77d4ac.bindPopup(popup_7a8a2a02d6c981e02017dd79c4d3319a)
#         ;
#
#
#
#
#             var circle_marker_e4add85f68f4310596040df5df3be68f = L.circleMarker(
#                 [21.6202, 80.6965],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5928d8f5852b666cf2691229bbe5e798);
#
#
#         var popup_99b88945305d8dcf2cfca5e05018b068 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d615c2a24efff3fb60bd96c6b72d4ed6 = $(`&lt;div id=&quot;html_d615c2a24efff3fb60bd96c6b72d4ed6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Poaching Incident&lt;/div&gt;`)[0];
#                 popup_99b88945305d8dcf2cfca5e05018b068.setContent(html_d615c2a24efff3fb60bd96c6b72d4ed6);
#
#
#
#         circle_marker_e4add85f68f4310596040df5df3be68f.bindPopup(popup_99b88945305d8dcf2cfca5e05018b068)
#         ;
#
#
#
#
#             var circle_marker_d08161d566a577cd0fc56def7d32c4a8 = L.circleMarker(
#                 [22.3575, 85.6671],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quo

# %%
import geopandas as gpd
import pandas as pd
import folium
from folium.plugins import HeatMap
from sklearn.cluster import KMeans

# Load India's map shapefile from the specified folder
india_map = gpd.read_file("gadm41_IND_shp/gadm41_IND_3.shp")  # Ensure this path is correct

# Load tiger population data (assuming you have lat/lon and population density)
tiger_population = pd.read_excel("TigerDataIBM.xlsx")  # Modify based on actual sheet

# Print column names to debug
print("Tiger Population Columns:", tiger_population.columns)

# Strip any extra spaces from the column names
tiger_population.columns = tiger_population.columns.str.strip()

# Check the updated column names after stripping spaces
print("Updated Tiger Population Columns:", tiger_population.columns)

# Prepare heatmap data using the correct column names
try:
    heatmap_data = [[row['Latitude'], row['Longitude'], row['Tiger Population']] for index, row in tiger_population.iterrows()]
except KeyError as e:
    print(f"KeyError: {e}. Please check your column names in the DataFrame.")

# Load poaching data (Lat/Lon of high-risk poaching areas)
poaching_data = pd.read_csv("poaching_data.csv")  # Example file containing Lat/Lon of poaching incidents

# Prepare poaching coordinates for clustering using the correct column names
poaching_coords = poaching_data[['Lat', 'Lon']].values

# Determine the number of clusters based on the number of poaching incidents (or adjust this number)
num_clusters = min(len(poaching_coords), 10)  # Max 10 devices or the number of incidents, whichever is smaller

# Apply K-means clustering to find device locations
kmeans = KMeans(n_clusters=num_clusters, n_init=10, random_state=42)  # Set n_init explicitly
kmeans.fit(poaching_coords)

# Get the cluster centers (device locations)
device_locations = kmeans.cluster_centers_

# Create a base map using Folium
m = folium.Map(location=[23.5937, 80.9629], zoom_start=5, tiles='CartoDB positron')

# Create the heatmap layer
if 'Latitude' in tiger_population.columns and 'Longitude' in tiger_population.columns and 'Tiger Population' in tiger_population.columns:
    HeatMap(heatmap_data, radius=15, max_zoom=13).add_to(m)

# Plot poaching data as red circles
for _, row in poaching_data.iterrows():
    folium.CircleMarker(
        location=(row['Lat'], row['Lon']),
        radius=6,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup="Poaching Incident"
    ).add_to(m)

# Plot device locations as blue markers
for device in device_locations:
    folium.Marker(
        location=(device[0], device[1]),
        popup="Proposed Device",
        icon=folium.Icon(color='blue')
    ).add_to(m)

# Display the map and save it as an HTML file
m.save('tiger_poaching_map.html')
m
# Out:
# Tiger Population Columns: Index(['ID', 'State/UT', 'Region/National Park', 'Tiger Population',
#        'Population Estimate', 'Conservation Status', 'Habitat Type', 'Threats',
#        'Conservation Initiatives', 'Tourism Impact', 'Latitude', 'Longitude',
#        'Notes'],
#       dtype='object')
# Updated Tiger Population Columns: Index(['ID', 'State/UT', 'Region/National Park', 'Tiger Population',
#        'Population Estimate', 'Conservation Status', 'Habitat Type', 'Threats',
#        'Conservation Initiatives', 'Tourism Impact', 'Latitude', 'Longitude',
#        'Notes'],
#       dtype='object')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77cfcd1247c5a7a1089461a846416666 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77cfcd1247c5a7a1089461a846416666&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77cfcd1247c5a7a1089461a846416666 = L.map(
#                 &quot;map_77cfcd1247c5a7a1089461a846416666&quot;,
#                 {
#                     center: [23.5937, 80.9629],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5693afe467d87e6bbac426e989839f1a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5693afe467d87e6bbac426e989839f1a.addTo(map_77cfcd1247c5a7a1089461a846416666);
#
#
#             var heat_map_72909142dc979bf14bfa50786f220efc = L.heatLayer(
#                 [[15.9129, 80.1924, 30], [28.218, 78.2424, 24], [26.2006, 91.5837, 103], [25.0968, 85.3131, 14], [21.2784, 81.8661, 19], [15.5522, 73.7518, 3], [22.2587, 72.5714, 22], [28.4595, 77.0975, 5], [31.1048, 77.4419, 12], [23.6102, 86.9894, 10], [15.3173, 75.7139, 300], [10.8505, 76.2711, 45], [22.9734, 78.6569, 526], [19.963, 72.8311, 260], [24.6637, 93.9, 12], [25.467, 91.5822, 25], [23.1645, 92.6372, 10], [26.1584, 94.1628, 10], [20.9517, 85.8201, 36], [30.7333, 75.695, 1], [27.0238, 69.895, 85], [27.5343, 88.1341, 0], [30.0668, 77.031, 66], [17.223, 78.332, 70], [23.829, 91.264, 30], [28.9878, 80.8607, 36], [30.7333, 79.0147, 2], [22.3431, 88.7982, 36], [11.623, 92.531, 0], [33.7782, 76.5762, 0]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 13, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 15}
#             );
#
#
#             heat_map_72909142dc979bf14bfa50786f220efc.addTo(map_77cfcd1247c5a7a1089461a846416666);
#
#
#             var circle_marker_c36f5fdbd6318f7170c7a97700bc8462 = L.circleMarker(
#                 [26.9205, 80.7734],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_77cfcd1247c5a7a1089461a846416666);
#
#
#         var popup_894879c6dbfe3b209abfc5bb894d46a3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b8eb4321a8c125b7fb39e8c7d28a4dc1 = $(`&lt;div id=&quot;html_b8eb4321a8c125b7fb39e8c7d28a4dc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Poaching Incident&lt;/div&gt;`)[0];
#                 popup_894879c6dbfe3b209abfc5bb894d46a3.setContent(html_b8eb4321a8c125b7fb39e8c7d28a4dc1);
#
#
#
#         circle_marker_c36f5fdbd6318f7170c7a97700bc8462.bindPopup(popup_894879c6dbfe3b209abfc5bb894d46a3)
#         ;
#
#
#
#
#             var circle_marker_607f1e4d8fcee728ce7770879e7d6c98 = L.circleMarker(
#                 [25.9785, 86.4706],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_77cfcd1247c5a7a1089461a846416666);
#
#
#         var popup_7b392c3a5961b84deb83dac946a9a4f4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_900edcc4bbb08b9ab1eb10077af09307 = $(`&lt;div id=&quot;html_900edcc4bbb08b9ab1eb10077af09307&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Poaching Incident&lt;/div&gt;`)[0];
#                 popup_7b392c3a5961b84deb83dac946a9a4f4.setContent(html_900edcc4bbb08b9ab1eb10077af09307);
#
#
#
#         circle_marker_607f1e4d8fcee728ce7770879e7d6c98.bindPopup(popup_7b392c3a5961b84deb83dac946a9a4f4)
#         ;
#
#
#
#
#             var circle_marker_1ece6fb4ba85cd2b8bc8f41d15d629a9 = L.circleMarker(
#                 [21.6202, 80.6965],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &qu

# %%
import geopandas as gpd
import pandas as pd
import folium
from folium.plugins import HeatMap
from sklearn.cluster import KMeans

# Load India's map shapefile from the specified folder
india_map = gpd.read_file("gadm41_IND_shp/gadm41_IND_3.shp")  # Ensure this path is correct

# Load tiger population data (assuming you have lat/lon and population density)
tiger_population = pd.read_excel("TigerDataIBM.xlsx")  # Modify based on actual sheet

# Print column names to debug
print("Tiger Population Columns:", tiger_population.columns)

# Strip any extra spaces from the column names
tiger_population.columns = tiger_population.columns.str.strip()

# Check the updated column names after stripping spaces
print("Updated Tiger Population Columns:", tiger_population.columns)

# Prepare heatmap data using the correct column names
try:
    heatmap_data = [[row['Latitude'], row['Longitude'], row['Tiger Population']] for index, row in tiger_population.iterrows()]
except KeyError as e:
    print(f"KeyError: {e}. Please check your column names in the DataFrame.")

# Load poaching data (Lat/Lon of high-risk poaching areas)
poaching_data = pd.read_csv("poaching_data.csv")  # Example file containing Lat/Lon of poaching incidents

# Prepare poaching coordinates for clustering using the correct column names
poaching_coords = poaching_data[['Lat', 'Lon']].values

# Determine the number of clusters based on the number of poaching incidents (increase this number for more devices)
num_clusters = min(len(poaching_coords), 20)  # Increase to 20 or another suitable number

# Apply K-means clustering to find device locations
kmeans = KMeans(n_clusters=num_clusters, n_init=10, random_state=42)  # Set n_init explicitly
kmeans.fit(poaching_coords)

# Get the cluster centers (device locations)
device_locations = kmeans.cluster_centers_

# Create a base map using Folium
m = folium.Map(location=[23.5937, 80.9629], zoom_start=5, tiles='CartoDB positron')

# Create the heatmap layer
if 'Latitude' in tiger_population.columns and 'Longitude' in tiger_population.columns and 'Tiger Population' in tiger_population.columns:
    HeatMap(heatmap_data, radius=15, max_zoom=13).add_to(m)

# Plot poaching data as red circles
for _, row in poaching_data.iterrows():
    folium.CircleMarker(
        location=(row['Lat'], row['Lon']),
        radius=6,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup="Poaching Incident"
    ).add_to(m)

# Plot device locations as blue markers
for device in device_locations:
    folium.Marker(
        location=(device[0], device[1]),
        popup="Proposed Device",
        icon=folium.Icon(color='blue')
    ).add_to(m)

# Display the map and save it as an HTML file
m.save('tiger_poaching_map.html')
m
# Out:
# Tiger Population Columns: Index(['ID', 'State/UT', 'Region/National Park', 'Tiger Population',
#        'Population Estimate', 'Conservation Status', 'Habitat Type', 'Threats',
#        'Conservation Initiatives', 'Tourism Impact', 'Latitude', 'Longitude',
#        'Notes'],
#       dtype='object')
# Updated Tiger Population Columns: Index(['ID', 'State/UT', 'Region/National Park', 'Tiger Population',
#        'Population Estimate', 'Conservation Status', 'Habitat Type', 'Threats',
#        'Conservation Initiatives', 'Tourism Impact', 'Latitude', 'Longitude',
#        'Notes'],
#       dtype='object')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_141fd458d859dcc7e2625928fe6662a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_141fd458d859dcc7e2625928fe6662a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_141fd458d859dcc7e2625928fe6662a1 = L.map(
#                 &quot;map_141fd458d859dcc7e2625928fe6662a1&quot;,
#                 {
#                     center: [23.5937, 80.9629],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10a317d11c554756bcb61036c363ca5a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_10a317d11c554756bcb61036c363ca5a.addTo(map_141fd458d859dcc7e2625928fe6662a1);
#
#
#             var heat_map_c22ac8733ae8d41c88de841e73eef892 = L.heatLayer(
#                 [[15.9129, 80.1924, 30], [28.218, 78.2424, 24], [26.2006, 91.5837, 103], [25.0968, 85.3131, 14], [21.2784, 81.8661, 19], [15.5522, 73.7518, 3], [22.2587, 72.5714, 22], [28.4595, 77.0975, 5], [31.1048, 77.4419, 12], [23.6102, 86.9894, 10], [15.3173, 75.7139, 300], [10.8505, 76.2711, 45], [22.9734, 78.6569, 526], [19.963, 72.8311, 260], [24.6637, 93.9, 12], [25.467, 91.5822, 25], [23.1645, 92.6372, 10], [26.1584, 94.1628, 10], [20.9517, 85.8201, 36], [30.7333, 75.695, 1], [27.0238, 69.895, 85], [27.5343, 88.1341, 0], [30.0668, 77.031, 66], [17.223, 78.332, 70], [23.829, 91.264, 30], [28.9878, 80.8607, 36], [30.7333, 79.0147, 2], [22.3431, 88.7982, 36], [11.623, 92.531, 0], [33.7782, 76.5762, 0]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 13, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 15}
#             );
#
#
#             heat_map_c22ac8733ae8d41c88de841e73eef892.addTo(map_141fd458d859dcc7e2625928fe6662a1);
#
#
#             var circle_marker_021e2aba97ea40fbbef8a554e8fd5c1b = L.circleMarker(
#                 [26.9205, 80.7734],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_141fd458d859dcc7e2625928fe6662a1);
#
#
#         var popup_477e15a3ef8407a3e53706055076e61f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4769f9d49faa663d4c6943360242ee3d = $(`&lt;div id=&quot;html_4769f9d49faa663d4c6943360242ee3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Poaching Incident&lt;/div&gt;`)[0];
#                 popup_477e15a3ef8407a3e53706055076e61f.setContent(html_4769f9d49faa663d4c6943360242ee3d);
#
#
#
#         circle_marker_021e2aba97ea40fbbef8a554e8fd5c1b.bindPopup(popup_477e15a3ef8407a3e53706055076e61f)
#         ;
#
#
#
#
#             var circle_marker_880a04aeaa6df4084f6d45b676faf5ff = L.circleMarker(
#                 [25.9785, 86.4706],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_141fd458d859dcc7e2625928fe6662a1);
#
#
#         var popup_63b88eb469a6f8db38174359d1595768 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9617364233d6a04cd0a4b0a015828214 = $(`&lt;div id=&quot;html_9617364233d6a04cd0a4b0a015828214&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Poaching Incident&lt;/div&gt;`)[0];
#                 popup_63b88eb469a6f8db38174359d1595768.setContent(html_9617364233d6a04cd0a4b0a015828214);
#
#
#
#         circle_marker_880a04aeaa6df4084f6d45b676faf5ff.bindPopup(popup_63b88eb469a6f8db38174359d1595768)
#         ;
#
#
#
#
#             var circle_marker_ef954bdd12ca058edae213cc3df6b86f = L.circleMarker(
#                 [21.6202, 80.6965],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &qu

# %%
import geopandas as gpd
import pandas as pd
import folium
from folium.plugins import HeatMap

# Load India's map shapefile from the specified folder
india_map = gpd.read_file("gadm41_IND_shp/gadm41_IND_3.shp")  # Ensure this path is correct

# Load tiger population data (assuming you have lat/lon and population density)
tiger_population = pd.read_excel("TigerDataIBM.xlsx")  # Modify based on actual sheet

# Print column names to debug
print("Tiger Population Columns:", tiger_population.columns)

# Strip any extra spaces from the column names
tiger_population.columns = tiger_population.columns.str.strip()

# Check the updated column names after stripping spaces
print("Updated Tiger Population Columns:", tiger_population.columns)

# Prepare heatmap data using the correct column names
try:
    heatmap_data = [[row['Latitude'], row['Longitude'], row['Tiger Population']] for index, row in tiger_population.iterrows()]
except KeyError as e:
    print(f"KeyError: {e}. Please check your column names in the DataFrame.")

# Load poaching data (Lat/Lon of high-risk poaching areas)
poaching_data = pd.read_csv("poaching_data.csv")  # Example file containing Lat/Lon of poaching incidents

# Prepare poaching coordinates for clustering using the correct column names
poaching_coords = poaching_data[['Lat', 'Lon']].values

# Create a base map using Folium
m = folium.Map(location=[23.5937, 80.9629], zoom_start=5, tiles='CartoDB positron')

# Create the heatmap layer
if 'Latitude' in tiger_population.columns and 'Longitude' in tiger_population.columns and 'Tiger Population' in tiger_population.columns:
    HeatMap(heatmap_data, radius=15, max_zoom=13).add_to(m)

# Plot poaching data as red circles (no blue device markers here)
for _, row in poaching_data.iterrows():
    folium.CircleMarker(
        location=(row['Lat'], row['Lon']),
        radius=6,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup="Poaching Incident"
    ).add_to(m)

# Display the map and save it as an HTML file
m.save('tiger_poaching_map_no_devices.html')
m
# Out:
# Tiger Population Columns: Index(['ID', 'State/UT', 'Region/National Park', 'Tiger Population',
#        'Population Estimate', 'Conservation Status', 'Habitat Type', 'Threats',
#        'Conservation Initiatives', 'Tourism Impact', 'Latitude', 'Longitude',
#        'Notes'],
#       dtype='object')
# Updated Tiger Population Columns: Index(['ID', 'State/UT', 'Region/National Park', 'Tiger Population',
#        'Population Estimate', 'Conservation Status', 'Habitat Type', 'Threats',
#        'Conservation Initiatives', 'Tourism Impact', 'Latitude', 'Longitude',
#        'Notes'],
#       dtype='object')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b41430332cb04bc79faa55cc53c4e86b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b41430332cb04bc79faa55cc53c4e86b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b41430332cb04bc79faa55cc53c4e86b = L.map(
#                 &quot;map_b41430332cb04bc79faa55cc53c4e86b&quot;,
#                 {
#                     center: [23.5937, 80.9629],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb4b95347420b740ce7b67b4c359f82a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bb4b95347420b740ce7b67b4c359f82a.addTo(map_b41430332cb04bc79faa55cc53c4e86b);
#
#
#             var heat_map_5c739d4629eb9fae528e5e6cd0e9f408 = L.heatLayer(
#                 [[15.9129, 80.1924, 30], [28.218, 78.2424, 24], [26.2006, 91.5837, 103], [25.0968, 85.3131, 14], [21.2784, 81.8661, 19], [15.5522, 73.7518, 3], [22.2587, 72.5714, 22], [28.4595, 77.0975, 5], [31.1048, 77.4419, 12], [23.6102, 86.9894, 10], [15.3173, 75.7139, 300], [10.8505, 76.2711, 45], [22.9734, 78.6569, 526], [19.963, 72.8311, 260], [24.6637, 93.9, 12], [25.467, 91.5822, 25], [23.1645, 92.6372, 10], [26.1584, 94.1628, 10], [20.9517, 85.8201, 36], [30.7333, 75.695, 1], [27.0238, 69.895, 85], [27.5343, 88.1341, 0], [30.0668, 77.031, 66], [17.223, 78.332, 70], [23.829, 91.264, 30], [28.9878, 80.8607, 36], [30.7333, 79.0147, 2], [22.3431, 88.7982, 36], [11.623, 92.531, 0], [33.7782, 76.5762, 0]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 13, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 15}
#             );
#
#
#             heat_map_5c739d4629eb9fae528e5e6cd0e9f408.addTo(map_b41430332cb04bc79faa55cc53c4e86b);
#
#
#             var circle_marker_9a246e69be051c01d6bc9eb731dc8cdc = L.circleMarker(
#                 [26.9205, 80.7734],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b41430332cb04bc79faa55cc53c4e86b);
#
#
#         var popup_85a1fb051ebb5ff9d3cc80220826d88b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_06cd2176c054d36b6698c35165fefacd = $(`&lt;div id=&quot;html_06cd2176c054d36b6698c35165fefacd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Poaching Incident&lt;/div&gt;`)[0];
#                 popup_85a1fb051ebb5ff9d3cc80220826d88b.setContent(html_06cd2176c054d36b6698c35165fefacd);
#
#
#
#         circle_marker_9a246e69be051c01d6bc9eb731dc8cdc.bindPopup(popup_85a1fb051ebb5ff9d3cc80220826d88b)
#         ;
#
#
#
#
#             var circle_marker_1c9f3d17eee62c1f0fd4a67518ae4f34 = L.circleMarker(
#                 [25.9785, 86.4706],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b41430332cb04bc79faa55cc53c4e86b);
#
#
#         var popup_f5d92e553daa1aa0a2cf1fabd295d0de = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5c5019b78862ace2c9bba4ca3a85cfb6 = $(`&lt;div id=&quot;html_5c5019b78862ace2c9bba4ca3a85cfb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Poaching Incident&lt;/div&gt;`)[0];
#                 popup_f5d92e553daa1aa0a2cf1fabd295d0de.setContent(html_5c5019b78862ace2c9bba4ca3a85cfb6);
#
#
#
#         circle_marker_1c9f3d17eee62c1f0fd4a67518ae4f34.bindPopup(popup_f5d92e553daa1aa0a2cf1fabd295d0de)
#         ;
#
#
#
#
#             var circle_marker_aede0ff2548978edf21e2d178d455491 = L.circleMarker(
#                 [21.6202, 80.6965],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &qu

# %%
import geopandas as gpd
import pandas as pd
import folium
from folium.plugins import HeatMap

# Load India's map shapefile from the specified folder
india_map = gpd.read_file("gadm41_IND_shp/gadm41_IND_3.shp")  # Ensure this path is correct

# Load tiger population data (assuming you have lat/lon and population density)
tiger_population = pd.read_excel("TigerDataIBM.xlsx")  # Modify based on actual sheet

# Print column names to debug
print("Tiger Population Columns:", tiger_population.columns)

# Strip any extra spaces from the column names
tiger_population.columns = tiger_population.columns.str.strip()

# Check the updated column names after stripping spaces
print("Updated Tiger Population Columns:", tiger_population.columns)

# Prepare heatmap data using the correct column names
try:
    heatmap_data = [[row['Latitude'], row['Longitude'], row['Tiger Population']] for index, row in tiger_population.iterrows()]
except KeyError as e:
    print(f"KeyError: {e}. Please check your column names in the DataFrame.")

# Load poaching data (Lat/Lon of high-risk poaching areas)
poaching_data = pd.read_csv("poaching_data.csv")  # Example file containing Lat/Lon of poaching incidents

# Prepare heatmap data for poaching incidents
poaching_heatmap_data = [[row['Lat'], row['Lon']] for index, row in poaching_data.iterrows()]

# Create a base map using Folium
m = folium.Map(location=[23.5937, 80.9629], zoom_start=5, tiles='CartoDB positron')

# Create a heatmap layer for poaching incidents
HeatMap(poaching_heatmap_data, radius=15, max_zoom=13).add_to(m)

# Display the map and save it as an HTML file
m.save('poaching_heatmap.html')
m
# Out:
# Tiger Population Columns: Index(['ID', 'State/UT', 'Region/National Park', 'Tiger Population',
#        'Population Estimate', 'Conservation Status', 'Habitat Type', 'Threats',
#        'Conservation Initiatives', 'Tourism Impact', 'Latitude', 'Longitude',
#        'Notes'],
#       dtype='object')
# Updated Tiger Population Columns: Index(['ID', 'State/UT', 'Region/National Park', 'Tiger Population',
#        'Population Estimate', 'Conservation Status', 'Habitat Type', 'Threats',
#        'Conservation Initiatives', 'Tourism Impact', 'Latitude', 'Longitude',
#        'Notes'],
#       dtype='object')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e71e61bd9f3b2bb65b18e99de379218a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e71e61bd9f3b2bb65b18e99de379218a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e71e61bd9f3b2bb65b18e99de379218a = L.map(
#                 &quot;map_e71e61bd9f3b2bb65b18e99de379218a&quot;,
#                 {
#                     center: [23.5937, 80.9629],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5c53439d1401e5f916abcf416a7f770b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5c53439d1401e5f916abcf416a7f770b.addTo(map_e71e61bd9f3b2bb65b18e99de379218a);
#
#
#             var heat_map_179fbfe309db28b9b0db82ee95e58a3a = L.heatLayer(
#                 [[26.9205, 80.7734], [25.9785, 86.4706], [21.6202, 80.6965], [22.3575, 85.6671], [27.2178, 78.2829], [20.4362, 79.2928], [23.2402, 80.3968], [26.2786, 92.7349], [24.0264, 82.0553], [25.3531, 84.0322], [26.8206, 82.7634], [23.5026, 80.2976], [27.931, 79.8035], [19.9376, 79.8836], [26.5858, 91.7373], [26.4482, 93.4682], [29.5745, 78.5707], [12.9765, 77.574], [24.7556, 82.6987], [26.0691, 74.61], [21.6196, 81.7572], [25.396, 92.5625], [24.0036, 75.5847], [21.2669, 78.9171], [24.5705, 77.726], [22.6667, 88.3667], [29.6062, 79.5669], [27.5171, 83.0891], [28.4801, 77.7064], [28.748, 76.8325], [21.9017, 76.8795], [11.4094, 76.6935], [11.6048, 77.2665], [11.8745, 76.8549], [10.2768, 77.2216], [22.1008, 82.1555], [12.7651, 75.7746], [25.0092, 81.1464], [24.6966, 73.6768], [20.3524, 79.2066], [26.8032, 93.9003], [27.565, 78.4826], [21.4314, 81.9345], [20.6828, 83.1291], [20.6303, 85.8352], [21.8235, 78.6207], [22.034, 80.128], [20.31, 84.86], [27.3074, 77.3864], [27.0181, 80.3353], [25.1122, 81.0674], [20.7623, 85.8401], [21.978, 80.8431], [21.124, 81.9439], [19.2472, 85.8189], [22.9568, 86.8023], [22.4863, 80.1864], [27.0902, 78.6495], [20.6817, 85.8251], [12.929, 77.606], [19.8103, 84.9576], [28.2042, 77.7061], [21.185, 81.835], [19.1394, 84.7954], [20.458, 78.508], [12.6872, 77.2002], [21.4294, 80.8009], [28.3624, 77.0584], [25.8506, 78.7866], [22.257, 75.1106], [21.7783, 79.5407], [23.0308, 79.5298], [20.6064, 84.799], [22.5944, 78.894], [23.2393, 78.6037], [20.4932, 79.9467], [22.1768, 75.8476], [19.1586, 84.74], [28.3128, 76.8463], [22.0482, 82.6585], [19.8905, 83.056], [20.3282, 85.6401], [19.8672, 84.5207], [19.1642, 85.8308], [12.8515, 77.5858], [20.385, 85.8113], [25.4444, 81.478], [20.942, 82.5265], [19.076, 83.488], [20.812, 80.918], [20.5576, 83.5769], [21.2086, 79.7636], [12.7092, 77.309], [22.5072, 79.8884], [26.5293, 83.0994], [19.9492, 85.8115], [19.8262, 84.535], [21.4335, 81.644], [12.9243, 77.5895], [25.6873, 81.5531], [22.267, 77.652], [20.6803, 83.133], [19.6464, 84.6631], [28.5564, 76.7864], [22.8487, 77.2379], [21.9735, 78.6306], [19.074, 84.7513], [23.4842, 81.8383], [20.6756, 85.81], [23.6707, 78.8567], [20.311, 85.7973], [19.9323, 85.8192], [21.0501, 79.0352], [26.747, 87.091], [19.6645, 84.5667], [20.9784, 85.8175], [19.5601, 84.6753], [20.7536, 85.6194], [12.546, 77.5835], [28.6754, 77.2211], [20.0454, 84.5462], [25.5751, 81.7101], [22.1867, 75.0084], [12.332, 77.7135], [25.1234, 81.115], [20.5405, 82.935], [20.6112, 84.3752], [22.3444, 76.187], [23.1095, 80.3195], [22.1212, 81.8091], [20.1876, 85.905], [26.7105, 87.844], [19.1856, 83.0672], [19.1346, 85.82], [25.4527, 81.327], [20.101, 85.7444], [22.3356, 75.677], [21.0916, 80.7564], [22.574, 75.7134], [21.7623, 81.1777], [20.446, 85.8292], [25.0807, 80.2064], [19.2163, 85.6016], [19.6122, 83.0925], [20.1776, 85.745], [12.8408, 77.6327], [19.841, 83.699], [22.271, 78.1974]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 13, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 15}
#             );
#
#
#             heat_map_179fbfe309db28b9b0db82ee95e58a3a.addTo(map_e71e61bd9f3b2bb65b18e99de379218a);
#
#
#             tile_layer_5c53439d1401e5f916abcf416a7f770b.addTo(map_e71e61bd9f3b2bb65b18e99de379218a);
#
#
#             heat_map_179fbfe309db28b9b0db82ee95e58a3a.addTo(map_e71e61bd9f3b2bb65b18e99de379218a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import geopandas as gpd
import pandas as pd
import folium
from folium.plugins import HeatMap
from sklearn.cluster import KMeans

# Load India's map shapefile from the specified folder
india_map = gpd.read_file("gadm41_IND_shp/gadm41_IND_3.shp")  # Ensure this path is correct

# Load tiger population data (assuming you have lat/lon and population density)
tiger_population = pd.read_excel("TigerDataIBM.xlsx")  # Modify based on actual sheet

# Print column names to debug
print("Tiger Population Columns:", tiger_population.columns)

# Strip any extra spaces from the column names
tiger_population.columns = tiger_population.columns.str.strip()

# Check the updated column names after stripping spaces
print("Updated Tiger Population Columns:", tiger_population.columns)

# Prepare heatmap data using the correct column names
try:
    heatmap_data = [[row['Latitude'], row['Longitude'], row['Tiger Population']] for index, row in tiger_population.iterrows()]
except KeyError as e:
    print(f"KeyError: {e}. Please check your column names in the DataFrame.")

# Load poaching data (Lat/Lon of high-risk poaching areas)
poaching_data = pd.read_csv("poaching_data.csv")  # Example file containing Lat/Lon of poaching incidents

# Prepare poaching coordinates for clustering using the correct column names
poaching_coords = poaching_data[['Lat', 'Lon']].values

# Determine the number of clusters based on the number of poaching incidents (increase this number for more devices)
num_clusters = min(len(poaching_coords), 20)  # Increase to 20 or another suitable number

# Apply K-means clustering to find device locations
kmeans = KMeans(n_clusters=num_clusters, n_init=10, random_state=42)  # Set n_init explicitly
kmeans.fit(poaching_coords)

# Get the cluster centers (device locations)
device_locations = kmeans.cluster_centers_

# Create a base map using Folium
m = folium.Map(location=[23.5937, 80.9629], zoom_start=5, tiles='CartoDB positron')

# Create the heatmap layer with a custom gradient to remove low-density blue spots
if 'Latitude' in tiger_population.columns and 'Longitude' in tiger_population.columns and 'Tiger Population' in tiger_population.columns:
    HeatMap(
        heatmap_data,
        radius=15,
        max_zoom=13,
        gradient={0.2: 'green', 0.4: 'yellow', 0.6: 'orange', 1: 'red'},  # Adjust the gradient to remove blue
    ).add_to(m)

# Plot poaching data as red circles
for _, row in poaching_data.iterrows():
    folium.CircleMarker(
        location=(row['Lat'], row['Lon']),
        radius=6,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup="Poaching Incident"
    ).add_to(m)

# Plot device locations as blue markers
for device in device_locations:
    folium.Marker(
        location=(device[0], device[1]),
        popup="Proposed Device",
        icon=folium.Icon(color='blue')
    ).add_to(m)

# Display the map and save it as an HTML file
m.save('tiger_poaching_map_no_random_blue_spots.html')
m
# Out:
# Tiger Population Columns: Index(['ID', 'State/UT', 'Region/National Park', 'Tiger Population',
#        'Population Estimate', 'Conservation Status', 'Habitat Type', 'Threats',
#        'Conservation Initiatives', 'Tourism Impact', 'Latitude', 'Longitude',
#        'Notes'],
#       dtype='object')
# Updated Tiger Population Columns: Index(['ID', 'State/UT', 'Region/National Park', 'Tiger Population',
#        'Population Estimate', 'Conservation Status', 'Habitat Type', 'Threats',
#        'Conservation Initiatives', 'Tourism Impact', 'Latitude', 'Longitude',
#        'Notes'],
#       dtype='object')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ecfefdf8a597ec28efbbce175500c208 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ecfefdf8a597ec28efbbce175500c208&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ecfefdf8a597ec28efbbce175500c208 = L.map(
#                 &quot;map_ecfefdf8a597ec28efbbce175500c208&quot;,
#                 {
#                     center: [23.5937, 80.9629],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_345e0ffafab2461a2638f3cae0bc0a07 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_345e0ffafab2461a2638f3cae0bc0a07.addTo(map_ecfefdf8a597ec28efbbce175500c208);
#
#
#             var heat_map_6c73b14a17b8ddafb70e8a03c8753d38 = L.heatLayer(
#                 [[15.9129, 80.1924, 30], [28.218, 78.2424, 24], [26.2006, 91.5837, 103], [25.0968, 85.3131, 14], [21.2784, 81.8661, 19], [15.5522, 73.7518, 3], [22.2587, 72.5714, 22], [28.4595, 77.0975, 5], [31.1048, 77.4419, 12], [23.6102, 86.9894, 10], [15.3173, 75.7139, 300], [10.8505, 76.2711, 45], [22.9734, 78.6569, 526], [19.963, 72.8311, 260], [24.6637, 93.9, 12], [25.467, 91.5822, 25], [23.1645, 92.6372, 10], [26.1584, 94.1628, 10], [20.9517, 85.8201, 36], [30.7333, 75.695, 1], [27.0238, 69.895, 85], [27.5343, 88.1341, 0], [30.0668, 77.031, 66], [17.223, 78.332, 70], [23.829, 91.264, 30], [28.9878, 80.8607, 36], [30.7333, 79.0147, 2], [22.3431, 88.7982, 36], [11.623, 92.531, 0], [33.7782, 76.5762, 0]],
#                 {&quot;blur&quot;: 15, &quot;gradient&quot;: {&quot;0.2&quot;: &quot;green&quot;, &quot;0.4&quot;: &quot;yellow&quot;, &quot;0.6&quot;: &quot;orange&quot;, &quot;1&quot;: &quot;red&quot;}, &quot;maxZoom&quot;: 13, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 15}
#             );
#
#
#             heat_map_6c73b14a17b8ddafb70e8a03c8753d38.addTo(map_ecfefdf8a597ec28efbbce175500c208);
#
#
#             var circle_marker_087c10b7e47e894b707c0b856d9724be = L.circleMarker(
#                 [26.9205, 80.7734],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ecfefdf8a597ec28efbbce175500c208);
#
#
#         var popup_81acbff75852e4d6cf44055ff08d8e0b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c527508ad2d2bff035ba2fdbc096bfe = $(`&lt;div id=&quot;html_0c527508ad2d2bff035ba2fdbc096bfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Poaching Incident&lt;/div&gt;`)[0];
#                 popup_81acbff75852e4d6cf44055ff08d8e0b.setContent(html_0c527508ad2d2bff035ba2fdbc096bfe);
#
#
#
#         circle_marker_087c10b7e47e894b707c0b856d9724be.bindPopup(popup_81acbff75852e4d6cf44055ff08d8e0b)
#         ;
#
#
#
#
#             var circle_marker_ff0e366665794e618a9314a0e171c8ce = L.circleMarker(
#                 [25.9785, 86.4706],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ecfefdf8a597ec28efbbce175500c208);
#
#
#         var popup_ae1ea133a94a143e6b21e561e7fcd99c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a51e094964c16559518902c9cade815c = $(`&lt;div id=&quot;html_a51e094964c16559518902c9cade815c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Poaching Incident&lt;/div&gt;`)[0];
#                 popup_ae1ea133a94a143e6b21e561e7fcd99c.setContent(html_a51e094964c16559518902c9cade815c);
#
#
#
#         circle_marker_ff0e366665794e618a9314a0e171c8ce.bindPopup(popup_ae1ea133a94a143e6b21e561e7fcd99c)
#         ;
#
#
#
#
#             var circle_marker_4748f37cef41e5b3eb63c12ca3103a7e = L.circleMarker(
#                 [21.6202, 80.6965],
#                 {&quot;bubblingMous

# %%
import geopandas as gpd
import pandas as pd
import folium
from folium.plugins import HeatMap
from sklearn.cluster import KMeans

# Load India's map shapefile from the specified folder
india_map = gpd.read_file("gadm41_IND_shp/gadm41_IND_3.shp")  # Ensure this path is correct

# Load tiger population data (assuming you have lat/lon and population density)
tiger_population = pd.read_excel("TigerDataIBM.xlsx")  # Modify based on actual sheet

# Print column names to debug
print("Tiger Population Columns:", tiger_population.columns)

# Strip any extra spaces from the column names
tiger_population.columns = tiger_population.columns.str.strip()

# Check the updated column names after stripping spaces
print("Updated Tiger Population Columns:", tiger_population.columns)

# Filter out low-density tiger population points to remove unwanted spots
min_population_threshold = 10  # Adjust this threshold as needed to remove low-density points
filtered_tiger_population = tiger_population[tiger_population['Tiger Population'] > min_population_threshold]

# Prepare heatmap data using the correct column names and filtered data
try:
    heatmap_data = [[row['Latitude'], row['Longitude'], row['Tiger Population']] for index, row in filtered_tiger_population.iterrows()]
except KeyError as e:
    print(f"KeyError: {e}. Please check your column names in the DataFrame.")

# Load poaching data (Lat/Lon of high-risk poaching areas)
poaching_data = pd.read_csv("poaching_data.csv")  # Example file containing Lat/Lon of poaching incidents

# Prepare poaching coordinates for clustering using the correct column names
poaching_coords = poaching_data[['Lat', 'Lon']].values

# Determine the number of clusters based on the number of poaching incidents (increase this number for more devices)
num_clusters = min(len(poaching_coords), 20)  # Increase to 20 or another suitable number

# Apply K-means clustering to find device locations
kmeans = KMeans(n_clusters=num_clusters, n_init=10, random_state=42)  # Set n_init explicitly
kmeans.fit(poaching_coords)

# Get the cluster centers (device locations)
device_locations = kmeans.cluster_centers_

# Create a base map using Folium
m = folium.Map(location=[23.5937, 80.9629], zoom_start=5, tiles='CartoDB positron')

# Create the heatmap layer without low-density areas
if 'Latitude' in tiger_population.columns and 'Longitude' in tiger_population.columns and 'Tiger Population' in tiger_population.columns:
    HeatMap(
        heatmap_data,
        radius=15,
        max_zoom=13,
        gradient={0.4: 'green', 0.6: 'orange', 1: 'red'},  # Show only mid- to high-density regions
        blur=20,  # Add some blur to make the heatmap smoother
        min_opacity=0.5  # Reduce opacity for low-density points
    ).add_to(m)

# Plot poaching data as red circles
for _, row in poaching_data.iterrows():
    folium.CircleMarker(
        location=(row['Lat'], row['Lon']),
        radius=6,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup="Poaching Incident"
    ).add_to(m)

# Plot device locations as blue markers
for device in device_locations:
    folium.Marker(
        location=(device[0], device[1]),
        popup="Proposed Device",
        icon=folium.Icon(color='blue')
    ).add_to(m)

# Display the map and save it as an HTML file
m.save('tiger_poaching_map_filtered.html')
m
# Out:
# Tiger Population Columns: Index(['ID', 'State/UT', 'Region/National Park', 'Tiger Population',
#        'Population Estimate', 'Conservation Status', 'Habitat Type', 'Threats',
#        'Conservation Initiatives', 'Tourism Impact', 'Latitude', 'Longitude',
#        'Notes'],
#       dtype='object')
# Updated Tiger Population Columns: Index(['ID', 'State/UT', 'Region/National Park', 'Tiger Population',
#        'Population Estimate', 'Conservation Status', 'Habitat Type', 'Threats',
#        'Conservation Initiatives', 'Tourism Impact', 'Latitude', 'Longitude',
#        'Notes'],
#       dtype='object')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fac3b5ef8d7d32633408fd0475f934a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fac3b5ef8d7d32633408fd0475f934a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fac3b5ef8d7d32633408fd0475f934a0 = L.map(
#                 &quot;map_fac3b5ef8d7d32633408fd0475f934a0&quot;,
#                 {
#                     center: [23.5937, 80.9629],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e00706b95e7983c3b9a221db675fa9b3 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e00706b95e7983c3b9a221db675fa9b3.addTo(map_fac3b5ef8d7d32633408fd0475f934a0);
#
#
#             var heat_map_a7bbb216898941b3c15256a4af0ba7e8 = L.heatLayer(
#                 [[15.9129, 80.1924, 30], [28.218, 78.2424, 24], [26.2006, 91.5837, 103], [25.0968, 85.3131, 14], [21.2784, 81.8661, 19], [22.2587, 72.5714, 22], [31.1048, 77.4419, 12], [15.3173, 75.7139, 300], [10.8505, 76.2711, 45], [22.9734, 78.6569, 526], [19.963, 72.8311, 260], [24.6637, 93.9, 12], [25.467, 91.5822, 25], [20.9517, 85.8201, 36], [27.0238, 69.895, 85], [30.0668, 77.031, 66], [17.223, 78.332, 70], [23.829, 91.264, 30], [28.9878, 80.8607, 36], [22.3431, 88.7982, 36]],
#                 {&quot;blur&quot;: 20, &quot;gradient&quot;: {&quot;0.4&quot;: &quot;green&quot;, &quot;0.6&quot;: &quot;orange&quot;, &quot;1&quot;: &quot;red&quot;}, &quot;maxZoom&quot;: 13, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 15}
#             );
#
#
#             heat_map_a7bbb216898941b3c15256a4af0ba7e8.addTo(map_fac3b5ef8d7d32633408fd0475f934a0);
#
#
#             var circle_marker_32fe108481ea58f7a8ebd5e4d9aaa257 = L.circleMarker(
#                 [26.9205, 80.7734],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fac3b5ef8d7d32633408fd0475f934a0);
#
#
#         var popup_460fb95fe6f489864e6f55b70f280f2c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8755f598cd3021ecf3980138216e85e3 = $(`&lt;div id=&quot;html_8755f598cd3021ecf3980138216e85e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Poaching Incident&lt;/div&gt;`)[0];
#                 popup_460fb95fe6f489864e6f55b70f280f2c.setContent(html_8755f598cd3021ecf3980138216e85e3);
#
#
#
#         circle_marker_32fe108481ea58f7a8ebd5e4d9aaa257.bindPopup(popup_460fb95fe6f489864e6f55b70f280f2c)
#         ;
#
#
#
#
#             var circle_marker_17832e7dc21712858ecee8413de37c72 = L.circleMarker(
#                 [25.9785, 86.4706],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fac3b5ef8d7d32633408fd0475f934a0);
#
#
#         var popup_96f0e723cca0c178c6340d8659a68800 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8f567cfbfa542d8e8ef5f4df5be14ca6 = $(`&lt;div id=&quot;html_8f567cfbfa542d8e8ef5f4df5be14ca6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Poaching Incident&lt;/div&gt;`)[0];
#                 popup_96f0e723cca0c178c6340d8659a68800.setContent(html_8f567cfbfa542d8e8ef5f4df5be14ca6);
#
#
#
#         circle_marker_17832e7dc21712858ecee8413de37c72.bindPopup(popup_96f0e723cca0c178c6340d8659a68800)
#         ;
#
#
#
#
#             var circle_marker_215ed92503a84856333d24b79b56ee6e = L.circleMarker(
#                 [21.6202, 80.6965],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&

# %%
import geopandas as gpd
import pandas as pd
import folium
from sklearn.cluster import KMeans
india_map = gpd.read_file("gadm41_IND_shp/gadm41_IND_3.shp")
tiger_population = pd.read_excel("TigerDataIBM.xlsx")
poaching_data = pd.read_csv("poaching_data.csv")
poaching_coords = poaching_data[['Lat', 'Lon']].values
num_clusters = min(len(poaching_coords), 20)
kmeans = KMeans(n_clusters=num_clusters, n_init=10, random_state=42)
kmeans.fit(poaching_coords)
device_locations = kmeans.cluster_centers_

# Create a base map using Folium
m = folium.Map(location=[23.5937, 80.9629], zoom_start=5, tiles='CartoDB positron')

# Plot poaching data as red circles
for _, row in poaching_data.iterrows():
    folium.CircleMarker(
        location=(row['Lat'], row['Lon']),
        radius=6,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup="Poaching Incident"
    ).add_to(m)

# Plot device locations as blue markers
for device in device_locations:
    folium.Marker(
        location=(device[0], device[1]),
        popup="Proposed Device",
        icon=folium.Icon(color='blue')
    ).add_to(m)

# Display the map and save it as an HTML file
m.save('tiger_poaching_map_no_heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0228e42578ed709bde4ac5618d9a4dc7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0228e42578ed709bde4ac5618d9a4dc7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0228e42578ed709bde4ac5618d9a4dc7 = L.map(
#                 &quot;map_0228e42578ed709bde4ac5618d9a4dc7&quot;,
#                 {
#                     center: [23.5937, 80.9629],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e30baa838df13eadb0842abedcc6a96 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9e30baa838df13eadb0842abedcc6a96.addTo(map_0228e42578ed709bde4ac5618d9a4dc7);
#
#
#             var circle_marker_3c75697a065fc566180f64c138acbff1 = L.circleMarker(
#                 [26.9205, 80.7734],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0228e42578ed709bde4ac5618d9a4dc7);
#
#
#         var popup_d1dd9027c281b52dbf7a94c84040d603 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c7949258223f5228479806ad89adb550 = $(`&lt;div id=&quot;html_c7949258223f5228479806ad89adb550&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Poaching Incident&lt;/div&gt;`)[0];
#                 popup_d1dd9027c281b52dbf7a94c84040d603.setContent(html_c7949258223f5228479806ad89adb550);
#
#
#
#         circle_marker_3c75697a065fc566180f64c138acbff1.bindPopup(popup_d1dd9027c281b52dbf7a94c84040d603)
#         ;
#
#
#
#
#             var circle_marker_24935b28dbe6b59af4a58c3a11126c35 = L.circleMarker(
#                 [25.9785, 86.4706],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0228e42578ed709bde4ac5618d9a4dc7);
#
#
#         var popup_66249072739a6a0862cf34fcdcdf3381 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_49f3b3b32575b1ba966d53f6b2463bc7 = $(`&lt;div id=&quot;html_49f3b3b32575b1ba966d53f6b2463bc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Poaching Incident&lt;/div&gt;`)[0];
#                 popup_66249072739a6a0862cf34fcdcdf3381.setContent(html_49f3b3b32575b1ba966d53f6b2463bc7);
#
#
#
#         circle_marker_24935b28dbe6b59af4a58c3a11126c35.bindPopup(popup_66249072739a6a0862cf34fcdcdf3381)
#         ;
#
#
#
#
#             var circle_marker_091cbe83a74049cbfd726905a81d4bf2 = L.circleMarker(
#                 [21.6202, 80.6965],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0228e42578ed709bde4ac5618d9a4dc7);
#
#
#         var popup_e7a75d100e2c090903d654eaeae84717 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04a23ddb8afd697085c9706382d7979e = $(`&lt;div id=&quot;html_04a23ddb8afd697085c9706382d7979e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Poaching Incident&lt;/div&gt;`)[0];
#                 popup_e7a75d100e2c090903d654eaeae84717.setContent(html_04a23ddb8afd697085c9706382d7979e);
#
#
#
#         circle_marker_091cbe83a74049cbfd726905a81d4bf2.bindPopup(popup_e7a75d100e2c090903d654eaeae84717)
#         ;
#
#
#
#
#             var circle_marker_95fb1612f5d596cd1cc5f8c99aacdd9a = L.circleMarker(
#                 [22.3575, 85.6671],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quo

# %%
from graphviz import Digraph

# Initialize a directed graph
dot = Digraph(comment='Tiger Poaching Corridor ER Diagram', format='png')
dot.attr(rankdir='LR', size='8,5')

# Define node attributes for entities
dot.node('Region', 'India Map (Region)', shape='box')
dot.node('TigerPop', 'Tiger Population', shape='box')
dot.node('PoachingInc', 'Poaching Incident', shape='box')
dot.node('DeviceLoc', 'Device Location', shape='box')

# Define relationships between entities
dot.edge('TigerPop', 'Region', label='Located_In')
dot.edge('PoachingInc', 'Region', label='Occurs_In')
dot.edge('DeviceLoc', 'PoachingInc', label='Monitors', dir='both')

# Define attributes for each entity in clusters for better organization

with dot.subgraph(name='cluster_Region') as region:
    region.attr(label='India Map (Region)')
    region.node('RegionID', 'RegionID')
    region.node('RegionName', 'RegionName')
    region.node('Latitude_Reg', 'Latitude')
    region.node('Longitude_Reg', 'Longitude')
    region.node('Area', 'Area')
    region.edge('Region', 'RegionID', style='dashed')
    region.edge('Region', 'RegionName', style='dashed')
    region.edge('Region', 'Latitude_Reg', style='dashed')
    region.edge('Region', 'Longitude_Reg', style='dashed')
    region.edge('Region', 'Area', style='dashed')

with dot.subgraph(name='cluster_TigerPop') as tigerpop:
    tigerpop.attr(label='Tiger Population')
    tigerpop.node('PopulationID', 'PopulationID')
    tigerpop.node('RegionID_TP', 'RegionID (FK)')
    tigerpop.node('Latitude_TP', 'Latitude')
    tigerpop.node('Longitude_TP', 'Longitude')
    tigerpop.node('PopulationDensity', 'PopulationDensity')
    tigerpop.edge('TigerPop', 'PopulationID', style='dashed')
    tigerpop.edge('TigerPop', 'RegionID_TP', style='dashed')
    tigerpop.edge('TigerPop', 'Latitude_TP', style='dashed')
    tigerpop.edge('TigerPop', 'Longitude_TP', style='dashed')
    tigerpop.edge('TigerPop', 'PopulationDensity', style='dashed')

with dot.subgraph(name='cluster_PoachingInc') as poachinc:
    poachinc.attr(label='Poaching Incident')
    poachinc.node('IncidentID', 'IncidentID')
    poachinc.node('Latitude_PI', 'Latitude')
    poachinc.node('Longitude_PI', 'Longitude')
    poachinc.node('Date', 'Date')
    poachinc.node('IncidentSeverity', 'IncidentSeverity')
    poachinc.edge('PoachingInc', 'IncidentID', style='dashed')
    poachinc.edge('PoachingInc', 'Latitude_PI', style='dashed')
    poachinc.edge('PoachingInc', 'Longitude_PI', style='dashed')
    poachinc.edge('PoachingInc', 'Date', style='dashed')
    poachinc.edge('PoachingInc', 'IncidentSeverity', style='dashed')

with dot.subgraph(name='cluster_DeviceLoc') as deviceloc:
    deviceloc.attr(label='Device Location')
    deviceloc.node('DeviceID', 'DeviceID')
    deviceloc.node('Latitude_DL', 'Latitude')
    deviceloc.node('Longitude_DL', 'Longitude')
    deviceloc.node('DeviceType', 'DeviceType')
    deviceloc.node('InstallationDate', 'InstallationDate')
    deviceloc.edge('DeviceLoc', 'DeviceID', style='dashed')
    deviceloc.edge('DeviceLoc', 'Latitude_DL', style='dashed')
    deviceloc.edge('DeviceLoc', 'Longitude_DL', style='dashed')
    deviceloc.edge('DeviceLoc', 'DeviceType', style='dashed')
    deviceloc.edge('DeviceLoc', 'InstallationDate', style='dashed')

# Render the diagram to a file
dot.render('/mnt/data/tiger_poaching_corridor_er_diagram')

'/mnt/data/tiger_poaching_corridor_er_diagram.png'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from graphviz import Digraph
#       3 # Initialize a directed graph
#       4 dot = Digraph(comment='Tiger Poaching Corridor ER Diagram', format='png')
#
# ModuleNotFoundError: No module named 'graphviz'

# %%
pip install graphviz
# Out:
# Collecting graphviz
#   Obtaining dependency information for graphviz from https://files.pythonhosted.org/packages/00/be/d59db2d1d52697c6adc9eacaf50e8965b6345cc143f671e1ed068818d5cf/graphviz-0.20.3-py3-none-any.whl.metadata
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/47.1 kB ? eta -:--:--
#    ---------------------------------------- 47.1/47.1 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: C:\Users\CJ\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
from graphviz import Digraph

# Initialize a directed graph with higher DPI
dot = Digraph(comment='Tiger Poaching Corridor ER Diagram', format='png')
dot.attr(dpi='300', rankdir='LR', size='8,5')  # Set DPI for higher resolution

# Define node attributes for entities
dot.node('Region', 'India Map (Region)', shape='box')
dot.node('TigerPop', 'Tiger Population', shape='box')
dot.node('PoachingInc', 'Poaching Incident', shape='box')
dot.node('DeviceLoc', 'Device Location', shape='box')

# Define relationships between entities
dot.edge('TigerPop', 'Region', label='Located_In')
dot.edge('PoachingInc', 'Region', label='Occurs_In')
dot.edge('DeviceLoc', 'PoachingInc', label='Monitors', dir='both')

# Define attributes for each entity in clusters for better organization
with dot.subgraph(name='cluster_Region') as region:
    region.attr(label='India Map (Region)')
    region.node('RegionID', 'RegionID')
    region.node('RegionName', 'RegionName')
    region.node('Latitude_Reg', 'Latitude')
    region.node('Longitude_Reg', 'Longitude')
    region.node('Area', 'Area')
    region.edge('Region', 'RegionID', style='dashed')
    region.edge('Region', 'RegionName', style='dashed')
    region.edge('Region', 'Latitude_Reg', style='dashed')
    region.edge('Region', 'Longitude_Reg', style='dashed')
    region.edge('Region', 'Area', style='dashed')

with dot.subgraph(name='cluster_TigerPop') as tigerpop:
    tigerpop.attr(label='Tiger Population')
    tigerpop.node('PopulationID', 'PopulationID')
    tigerpop.node('RegionID_TP', 'RegionID (FK)')
    tigerpop.node('Latitude_TP', 'Latitude')
    tigerpop.node('Longitude_TP', 'Longitude')
    tigerpop.node('PopulationDensity', 'PopulationDensity')
    tigerpop.edge('TigerPop', 'PopulationID', style='dashed')
    tigerpop.edge('TigerPop', 'RegionID_TP', style='dashed')
    tigerpop.edge('TigerPop', 'Latitude_TP', style='dashed')
    tigerpop.edge('TigerPop', 'Longitude_TP', style='dashed')
    tigerpop.edge('TigerPop', 'PopulationDensity', style='dashed')

with dot.subgraph(name='cluster_PoachingInc') as poachinc:
    poachinc.attr(label='Poaching Incident')
    poachinc.node('IncidentID', 'IncidentID')
    poachinc.node('Latitude_PI', 'Latitude')
    poachinc.node('Longitude_PI', 'Longitude')
    poachinc.node('Date', 'Date')
    poachinc.node('IncidentSeverity', 'IncidentSeverity')
    poachinc.edge('PoachingInc', 'IncidentID', style='dashed')
    poachinc.edge('PoachingInc', 'Latitude_PI', style='dashed')
    poachinc.edge('PoachingInc', 'Longitude_PI', style='dashed')
    poachinc.edge('PoachingInc', 'Date', style='dashed')
    poachinc.edge('PoachingInc', 'IncidentSeverity', style='dashed')

with dot.subgraph(name='cluster_DeviceLoc') as deviceloc:
    deviceloc.attr(label='Device Location')
    deviceloc.node('DeviceID', 'DeviceID')
    deviceloc.node('Latitude_DL', 'Latitude')
    deviceloc.node('Longitude_DL', 'Longitude')
    deviceloc.node('DeviceType', 'DeviceType')
    deviceloc.node('InstallationDate', 'InstallationDate')
    deviceloc.edge('DeviceLoc', 'DeviceID', style='dashed')
    deviceloc.edge('DeviceLoc', 'Latitude_DL', style='dashed')
    deviceloc.edge('DeviceLoc', 'Longitude_DL', style='dashed')
    deviceloc.edge('DeviceLoc', 'DeviceType', style='dashed')
    deviceloc.edge('DeviceLoc', 'InstallationDate', style='dashed')

# Render the diagram to a file
dot.render(r"C:\Users\CJ\OneDrive\Documents\Sem5\Predictive Analysis\tiger_poaching_corridor_er_diagram")
# Out:
# 'C:\\Users\\CJ\\OneDrive\\Documents\\Sem5\\Predictive Analysis\\tiger_poaching_corridor_er_diagram.png'

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# Generate sample data
n_samples = 300
n_features = 2
n_clusters = 3
X, _ = make_blobs(n_samples=n_samples, centers=n_clusters, n_features=n_features, random_state=42)

# Initialize the figure and axes
fig, ax = plt.subplots()
ax.set_title("K-Means Clustering")
ax.set_xlim(min(X[:, 0]) - 1, max(X[:, 0]) + 1)
ax.set_ylim(min(X[:, 1]) - 1, max(X[:, 1]) + 1)

# Plot data points
scatter = ax.scatter(X[:, 0], X[:, 1], c='gray', alpha=0.6)

# Initialize centroids
centroids = X[np.random.choice(X.shape[0], n_clusters, replace=False)]
centroid_scatter = ax.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='x')

# Function to update the animation
def update(frame):
    global centroids
    # Assign each point to the nearest centroid
    distances = np.linalg.norm(X[:, np.newaxis] - centroids, axis=2)
    labels = np.argmin(distances, axis=1)

    # Update centroids
    new_centroids = np.array([X[labels == i].mean(axis=0) for i in range(n_clusters)])
    
    # Update the scatter plot with new centroids
    centroid_scatter.set_offsets(new_centroids)
    
    # Update the colors of the points based on labels
    scatter.set_array(labels)

    centroids = new_centroids

# Create the animation
ani = FuncAnimation(fig, update, frames=10, interval=1000, repeat=False)

# Save as a gif
gif_path = '/mnt/data/kmeans_clustering.gif'
ani.save(gif_path, writer='imagemagick')

gif_path
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.
# '/mnt/data/kmeans_clustering.gif'

# %%
# Recreating the animation with more frames to ensure smooth animation

# Generate the same data again
n_samples = 300
n_features = 2
n_clusters = 3
X, _ = make_blobs(n_samples=n_samples, centers=n_clusters, n_features=n_features, random_state=42)

# Set up the figure and axes
fig, ax = plt.subplots()
ax.set_title("K-Means Clustering Animation")
ax.set_xlim(min(X[:, 0]) - 1, max(X[:, 0]) + 1)
ax.set_ylim(min(X[:, 1]) - 1, max(X[:, 1]) + 1)

# Initialize the scatter plots
scatter = ax.scatter(X[:, 0], X[:, 1], c='gray', alpha=0.6)
centroids = X[np.random.choice(X.shape[0], n_clusters, replace=False)]
centroid_scatter = ax.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='x')

# Function to update the animation
def update(frame):
    global centroids
    # Compute distances and assign labels
    distances = np.linalg.norm(X[:, np.newaxis] - centroids, axis=2)
    labels = np.argmin(distances, axis=1)

    # Calculate new centroids
    new_centroids = np.array([X[labels == i].mean(axis=0) for i in range(n_clusters)])
    
    # Update centroid positions and data point colors
    centroid_scatter.set_offsets(new_centroids)
    scatter.set_array(labels)

    centroids = new_centroids

# Creating a smoother animation with 20 frames
ani = FuncAnimation(fig, update, frames=20, interval=500, repeat=False)

# Save the new animation as a gif
gif_path = '/mnt/data/kmeans_clustering_animation.gif'
ani.save(gif_path, writer='imagemagick')

gif_path
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.
# '/mnt/data/kmeans_clustering_animation.gif'

# %%
pip install imagemagick
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement imagemagick (from versions: none)
# ERROR: No matching distribution found for imagemagick
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: C:\Users\CJ\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
pip install wand
# Out:
# Collecting wandNote: you may need to restart the kernel to use updated packages.
#
#   Obtaining dependency information for wand from https://files.pythonhosted.org/packages/59/d5/1bdd7c9662d5e9078e25ba0eb69bdb122859295746d40ab8dfef3a7b4d42/Wand-0.6.13-py2.py3-none-any.whl.metadata
#   Downloading Wand-0.6.13-py2.py3-none-any.whl.metadata (4.0 kB)
# Downloading Wand-0.6.13-py2.py3-none-any.whl (143 kB)
#    ---------------------------------------- 0.0/143.8 kB ? eta -:--:--
#    ------------------------------------- -- 133.1/143.8 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 143.8/143.8 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: wand
# Successfully installed wand-0.6.13
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000213A6752090>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /packages/59/d5/1bdd7c9662d5e9078e25ba0eb69bdb122859295746d40ab8dfef3a7b4d42/Wand-0.6.13-py2.py3-none-any.whl.metadata
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: C:\Users\CJ\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# Generate the same data again
n_samples = 300
n_features = 2
n_clusters = 3
X, _ = make_blobs(n_samples=n_samples, centers=n_clusters, n_features=n_features, random_state=42)

# Set up the figure and axes for the animation
fig, ax = plt.subplots()
ax.set_title("K-Means Clustering Animation")
ax.set_xlim(min(X[:, 0]) - 1, max(X[:, 0]) + 1)
ax.set_ylim(min(X[:, 1]) - 1, max(X[:, 1]) + 1)

# Initialize centroids
centroids = X[np.random.choice(X.shape[0], n_clusters, replace=False)]

# List to hold filenames of individual frames
frame_files = []

# Function to update the animation and save each frame
def update_and_save_frame(frame):
    global centroids
    # Compute distances and assign labels
    distances = np.linalg.norm(X[:, np.newaxis] - centroids, axis=2)
    labels = np.argmin(distances, axis=1)

    # Calculate new centroids
    new_centroids = np.array([X[labels == i].mean(axis=0) for i in range(n_clusters)])

    # Plotting the points and centroids
    ax.cla()  # Clear the axes
    ax.set_title("K-Means Clustering Animation")
    ax.set_xlim(min(X[:, 0]) - 1, max(X[:, 0]) + 1)
    ax.set_ylim(min(X[:, 1]) - 1, max(X[:, 1]) + 1)
    scatter = ax.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', alpha=0.6)
    centroid_scatter = ax.scatter(new_centroids[:, 0], new_centroids[:, 1], c='red', marker='x')

    # Save the current frame
    filename = f'frame_{frame}.png'
    plt.savefig(filename)
    frame_files.append(filename)

    centroids = new_centroids

# Generate frames for the animation
n_frames = 20
for frame in range(n_frames):
    update_and_save_frame(frame)

# Close the plot to avoid extra output
plt.close()

# Step 2: Create the animated GIF using ImageMagick
import os
import subprocess

# Use ImageMagick to create the GIF from the frames
gif_path = '/mnt/data/kmeans_clustering_animation.gif'
frame_files_str = ' '.join(frame_files)
cmd = f"convert -delay 10 -loop 0 {frame_files_str} {gif_path}"
subprocess.run(cmd, shell=True)

# Clean up the individual frame images
for file in frame_files:
    os.remove(file)

gif_path
# Out:
# '/mnt/data/kmeans_clustering_animation.gif'

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import os
import subprocess

# Ensure the output directory exists
output_dir = r'C:\Users\CJ\OneDrive\Documents\Sem5\Predictive Analysis'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Generate the same data again
n_samples = 300
n_features = 2
n_clusters = 3
X, _ = make_blobs(n_samples=n_samples, centers=n_clusters, n_features=n_features, random_state=42)

# Set up the figure and axes for the animation
fig, ax = plt.subplots()
ax.set_title("K-Means Clustering Animation")
ax.set_xlim(min(X[:, 0]) - 1, max(X[:, 0]) + 1)
ax.set_ylim(min(X[:, 1]) - 1, max(X[:, 1]) + 1)

# Initialize centroids
centroids = X[np.random.choice(X.shape[0], n_clusters, replace=False)]

# List to hold filenames of individual frames
frame_files = []

# Function to update the animation and save each frame
def update_and_save_frame(frame):
    global centroids
    # Compute distances and assign labels
    distances = np.linalg.norm(X[:, np.newaxis] - centroids, axis=2)
    labels = np.argmin(distances, axis=1)

    # Calculate new centroids
    new_centroids = np.array([X[labels == i].mean(axis=0) for i in range(n_clusters)])

    # Plotting the points and centroids
    ax.cla()  # Clear the axes
    ax.set_title("K-Means Clustering Animation")
    ax.set_xlim(min(X[:, 0]) - 1, max(X[:, 0]) + 1)
    ax.set_ylim(min(X[:, 1]) - 1, max(X[:, 1]) + 1)
    scatter = ax.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', alpha=0.6)
    centroid_scatter = ax.scatter(new_centroids[:, 0], new_centroids[:, 1], c='red', marker='x')

    # Save the current frame
    filename = os.path.join(output_dir, f'frame_{frame}.png')
    plt.savefig(filename)
    frame_files.append(filename)

    centroids = new_centroids

# Generate frames for the animation
n_frames = 20
for frame in range(n_frames):
    update_and_save_frame(frame)

# Close the plot to avoid extra output
plt.close()

# Step 2: Create the animated GIF using ImageMagick
gif_path = os.path.join(output_dir, 'kmeans_clustering_animation.gif')
frame_files_str = ' '.join(frame_files)
cmd = f"convert -delay 10 -loop 0 {frame_files_str} {gif_path}"

# Run the ImageMagick command to create the GIF
subprocess.run(cmd, shell=True)

# Clean up the individual frame images
for file in frame_files:
    os.remove(file)

print(f"GIF saved at: {gif_path}")
# Out:
# GIF saved at: C:\Users\CJ\OneDrive\Documents\Sem5\Predictive Analysis\kmeans_clustering_animation.gif

# %%
from graphviz import Digraph

# Create a new Digraph object
flowchart = Digraph('CompleteFlowchart', filename='complete_flowchart_yolov11', format='png')
flowchart.attr(rankdir='TB', size='10,15')

# Define nodes for the flowchart
flowchart.node('Start', 'Start', shape='ellipse')
flowchart.node('MotionSensor', 'Motion Sensor', shape='parallelogram')
flowchart.node('Camera', 'Camera Sensor', shape='parallelogram')
flowchart.node('RaspberryPi', 'Raspberry Pi', shape='rectangle')
flowchart.node('VideoUpload', 'Upload Video to EC2', shape='rectangle')
flowchart.node('EC2', 'AWS EC2 Instance', shape='rectangle')
flowchart.node('YOLOv11', 'YOLOv11 Detection Model', shape='rectangle')
flowchart.node('Detection', 'Human Detection\nLabel: "Potential Poacher"', shape='rectangle')
flowchart.node('Storage', 'Store Detected Images\n& Metadata', shape='cylinder')
flowchart.node('Analysis', 'Run Analytics', shape='rectangle')
flowchart.node('Jenkins', 'Jenkins CI/CD', shape='rectangle')
flowchart.node('Alert', 'Send Alert/Notification', shape='parallelogram')
flowchart.node('Output', 'Generate Output Video', shape='rectangle')
flowchart.node('End', 'End', shape='ellipse')

# Define edges between nodes to show the flow
flowchart.edge('Start', 'MotionSensor', label='Triggered by Movement')
flowchart.edge('MotionSensor', 'Camera', label='Activates Camera')
flowchart.edge('Camera', 'RaspberryPi', label='Captures Video Feed')
flowchart.edge('RaspberryPi', 'VideoUpload', label='Processes & Uploads')
flowchart.edge('VideoUpload', 'EC2', label='Video Feed Uploaded')
flowchart.edge('EC2', 'YOLOv11', label='Runs YOLOv11 Detection')
flowchart.edge('YOLOv11', 'Detection', label='Detect Humans')
flowchart.edge('Detection', 'Storage', label='Store Data')
flowchart.edge('Detection', 'Output', label='Generate Video')
flowchart.edge('Storage', 'Analysis', label='Analyze Patterns')
flowchart.edge('Analysis', 'Alert', label='If Threat Detected')
flowchart.edge('Jenkins', 'EC2', label='Manages Deployment')
flowchart.edge('Alert', 'End', label='Alert Sent')
flowchart.edge('Output', 'End', label='Process Complete')

# Render the flowchart
flowchart.render()
# Out:
# 'complete_flowchart_yolov11.png'

# %%
from graphviz import Digraph

# Create a new Digraph object
flowchart = Digraph('CompleteFlowchart', filename='complete_flowchart_yolov11_A4', format='png')

# Set the orientation and page size to fit A4 (8.3 x 11.7 inches)
flowchart.attr(rankdir='TB', size='8.3,11.7', page='8.3,11.7')

# Define nodes for the flowchart
flowchart.node('Start', 'Start', shape='ellipse')
flowchart.node('MotionSensor', 'Motion Sensor', shape='parallelogram')
flowchart.node('Camera', 'Camera Sensor', shape='parallelogram')
flowchart.node('RaspberryPi', 'Raspberry Pi', shape='rectangle')
flowchart.node('VideoUpload', 'Upload Video to EC2', shape='rectangle')
flowchart.node('EC2', 'AWS EC2 Instance', shape='rectangle')
flowchart.node('YOLOv11', 'YOLOv11 Detection Model', shape='rectangle')
flowchart.node('Detection', 'Human Detection\nLabel: "Potential Poacher"', shape='rectangle')
flowchart.node('Storage', 'Store Detected Images\n& Metadata', shape='cylinder')
flowchart.node('Analysis', 'Run Analytics', shape='rectangle')
flowchart.node('Jenkins', 'Jenkins CI/CD', shape='rectangle')
flowchart.node('Alert', 'Send Alert/Notification', shape='parallelogram')
flowchart.node('Output', 'Generate Output Video', shape='rectangle')
flowchart.node('End', 'End', shape='ellipse')

# Define edges between nodes to show the flow
flowchart.edge('Start', 'MotionSensor', label='Triggered by Movement')
flowchart.edge('MotionSensor', 'Camera', label='Activates Camera')
flowchart.edge('Camera', 'RaspberryPi', label='Captures Video Feed')
flowchart.edge('RaspberryPi', 'VideoUpload', label='Processes & Uploads')
flowchart.edge('VideoUpload', 'EC2', label='Video Feed Uploaded')
flowchart.edge('EC2', 'YOLOv11', label='Runs YOLOv11 Detection')
flowchart.edge('YOLOv11', 'Detection', label='Detect Humans')
flowchart.edge('Detection', 'Storage', label='Store Data')
flowchart.edge('Detection', 'Output', label='Generate Video')
flowchart.edge('Storage', 'Analysis', label='Analyze Patterns')
flowchart.edge('Analysis', 'Alert', label='If Threat Detected')
flowchart.edge('Jenkins', 'EC2', label='Manages Deployment')
flowchart.edge('Alert', 'End', label='Alert Sent')
flowchart.edge('Output', 'End', label='Process Complete')

# Render the flowchart
flowchart.render()
# Out:
# 'complete_flowchart_yolov11_A4.png'
